# %% [markdown]
# # simulation

# %%
from utils import (load_problem_data,
                   load_solution)
from evaluation_nofail import evaluation_function, get_known, get_evaluation
import evaluation_nofail
import evaluation as evaluation_fail
import pandas as pd
import numpy as np

demand, datacenters, servers, selling_prices = load_problem_data(path='./data_test')

# %%
def parse_action_string(action_string):
    server_generation, actions, action_params = action_string.split("|")
    actions = actions.split("-")
    action_params = action_params.split("-")
    action_comb = [parse_action_comb_param(server_generation, action, action_param) for action, action_param in zip(actions, action_params)]
    action_comb = [action for action in action_comb if action is not None]
    return action_comb
    
def parse_action_comb_param(server_generation, action, action_param):
    if action == "buy":
        datacenter_id, average_U = action_param.split(",")
        average_U = float(average_U)
        return {"action": action, "datacenter_id": datacenter_id, "average_U": average_U, "server_generation": server_generation}
    elif action == "dismiss":
        dismiss_age = int(action_param)
        return {"action": action, "dismiss_age": dismiss_age, "server_generation": server_generation}
    elif action == "move":
        datacenter_id, average_U, move_age = action_param.split(",")
        average_U = float(average_U)
        move_age = int(move_age)
        return {"action": action, "datacenter_id": datacenter_id, "average_U": average_U, "move_age": move_age,}
    return None

action_comb = parse_action_string("GPU.S3|buy-dismiss|DC3,0.5-84")
action_comb
# Out:
# [{'action': 'buy',
#   'datacenter_id': 'DC3',
#   'average_U': 0.5,
#   'server_generation': 'GPU.S3'},
#  {'action': 'dismiss', 'dismiss_age': 84, 'server_generation': 'GPU.S3'}]

# %%
def get_solution_from_action_comb(action_comb):
    solution = []
    for action in action_comb:
        if action["action"] == "buy":
            datacenter_id = action["datacenter_id"]
            server_generation = action["server_generation"]
            solution.append({"time_step": 1, 
                             "datacenter_id": datacenter_id, 
                             "server_generation": server_generation, 
                             "server_id": "7ee8a1de-b4b8-4fce-9bd6-19fdf8c1e409", 
                             "action": "buy"})
        elif action["action"] == "dismiss":
            dismiss_age = action["dismiss_age"]
            solution.append({"time_step": 1+dismiss_age, 
                             "datacenter_id": datacenter_id, 
                             "server_generation": server_generation, 
                             "server_id": "7ee8a1de-b4b8-4fce-9bd6-19fdf8c1e409", 
                             "action": "dismiss"})
        elif action["action"] == "move":
            datacenter_id = action["datacenter_id"]
            move_age = action["move_age"]
            solution.append({"time_step": 1+move_age, 
                             "datacenter_id": datacenter_id, 
                             "server_generation": server_generation, 
                             "server_id": "7ee8a1de-b4b8-4fce-9bd6-19fdf8c1e409", 
                             "action": "move"})
    solution = pd.DataFrame(solution)
    return solution
solution = get_solution_from_action_comb(action_comb)

# %%
df_servers = pd.read_csv('./data/servers.csv')
df_datacenters = pd.read_csv('./data/datacenters.csv')

# %%
import re

df_results = []
# for action_string in list_action_strings:
for action_string in ["CPU.S1|buy-dismiss|DC1,0.6-24"]:
    action_comb = parse_action_string(action_string)
    solution = get_solution_from_action_comb(action_comb)
    server_generation = action_comb[0]["server_generation"]
    latency_sensitivity = df_datacenters[df_datacenters['datacenter_id'] == action_comb[0]["datacenter_id"]]['latency_sensitivity'].iloc[0]

    server_capacity = df_servers[df_servers['server_generation'] == server_generation]['capacity'].iloc[0]
    average_U = action_comb[0]["average_U"]
    demand = pd.DataFrame({
        "time_step": list(range(1,168+1)),
        "server_generation": [server_generation]*168,
        "high": [0]*168,
        "medium": [0]*168,
        "low": [0]*168
    })
    demand[latency_sensitivity] = server_capacity * average_U
    evaluation_nofail.FAILTURE_RATE = 0.07260491698699582 * 0.0
    score = evaluation_nofail.get_evaluation(solution, 
                                            demand,
                                            datacenters,
                                            servers,
                                            selling_prices,
                                            time_steps=196, 
                                            verbose=True,
                                            random_demand=False)
    real_score = evaluation_fail.get_evaluation(solution, 
                                            demand,
                                            datacenters,
                                            servers,
                                            selling_prices,
                                            time_steps=196, 
                                            verbose=False,
                                            random_demand=False)
    print(action_string, score, real_score)
    df_results.append([action_string, score, real_score])
    
df_results = pd.DataFrame(df_results, columns=['action_string', 'score', 'real_score'])
df_results
# Out:
# {'time-step': 1, 'O': np.float64(-93.76), 'U': np.float64(0.6), 'L': np.float64(0.0104), 'P': np.float64(-15001.0), 'R': np.float64(360.0), 'C': np.float64(15361.0)}
# {'time-step': 2, 'O': np.float64(-93.54), 'U': np.float64(0.6), 'L': np.float64(0.0208), 'P': np.float64(17.0), 'R': np.float64(360.0), 'C': np.float64(343.0)}
# {'time-step': 3, 'O': np.float64(-92.95), 'U': np.float64(0.6), 'L': np.float64(0.0312), 'P': np.float64(31.6), 'R': np.float64(360.0), 'C': np.float64(328.4)}
# {'time-step': 4, 'O': np.float64(-91.85), 'U': np.float64(0.6), 'L': np.float64(0.0417), 'P': np.float64(44.0), 'R': np.float64(360.0), 'C': np.float64(316.0)}
# {'time-step': 5, 'O': np.float64(-90.14), 'U': np.float64(0.6), 'L': np.float64(0.0521), 'P': np.float64(54.76), 'R': np.float64(360.0), 'C': np.float64(305.24)}
# {'time-step': 6, 'O': np.float64(-87.73), 'U': np.float64(0.6), 'L': np.float64(0.0625), 'P': np.float64(64.21), 'R': np.float64(360.0), 'C': np.float64(295.79)}
# {'time-step': 7, 'O': np.float64(-84.56), 'U': np.float64(0.6), 'L': np.float64(0.0729), 'P': np.float64(72.57), 'R': np.float64(360.0), 'C': np.float64(287.43)}
# {'time-step': 8, 'O': np.float64(-80.56), 'U': np.float64(0.6), 'L': np.float64(0.0833), 'P': np.float64(80.0), 'R': np.float64(360.0), 'C': np.float64(280.0)}
# {'time-step': 9, 'O': np.float64(-75.69), 'U': np.float64(0.6), 'L': np.float64(0.0938), 'P': np.float64(86.62), 'R': np.float64(360.0), 'C': np.float64(273.38)}
# {'time-step': 10, 'O': np.float64(-69.9), 'U': np.float64(0.6), 'L': np.float64(0.1042), 'P': np.float64(92.51), 'R': np.float64(360.0), 'C': np.float64(267.49)}
# {'time-step': 11, 'O': np.float64(-63.18), 'U': np.float64(0.6), 'L': np.float64(0.1146), 'P': np.float64(97.76), 'R': np.float64(360.0), 'C': np.float64(262.24)}
# {'time-step': 12, 'O': np.float64(-55.5), 'U': np.float64(0.6), 'L': np.float64(0.125), 'P': np.float64(102.41), 'R': np.float64(360.0), 'C': np.float64(257.59)}
# {'time-step': 13, 'O': np.float64(-46.85), 'U': np.float64(0.6), 'L': np.float64(0.1354), 'P': np.float64(106.52), 'R': np.float64(360.0), 'C': np.float64(253.48)}
# {'time-step': 14, 'O': np.float64(-37.21), 'U': np.float64(0.6), 'L': np.float64(0.1458), 'P': np.float64(110.14), 'R': np.float64(360.0), 'C': np.float64(249.86)}
# {'time-step': 15, 'O': np.float64(-26.59), 'U': np.float64(0.6), 'L': np.float64(0.1562), 'P': np.float64(113.28), 'R': np.float64(360.0), 'C': np.float64(246.72)}
# {'time-step': 16, 'O': np.float64(-14.99), 'U': np.float64(0.6), 'L': np.float64(0.1667), 'P': np.float64(116.0), 'R': np.float64(360.0), 'C': np.float64(244.0)}
# {'time-step': 17, 'O': np.float64(-2.42), 'U': np.float64(0.6), 'L': np.float64(0.1771), 'P': np.float64(118.31), 'R': np.float64(360.0), 'C': np.float64(241.69)}
# {'time-step': 18, 'O': np.float64(11.11), 'U': np.float64(0.6), 'L': np.float64(0.1875), 'P': np.float64(120.24), 'R': np.float64(360.0), 'C': np.float64(239.76)}
# {'time-step': 19, 'O': np.float64(25.57), 'U': np.float64(0.6), 'L': np.float64(0.1979), 'P': np.float64(121.8), 'R': np.float64(360.0), 'C': np.float64(238.2)}
# {'time-step': 20, 'O': np.float64(40.95), 'U': np.float64(0.6), 'L': np.float64(0.2083), 'P': np.float64(123.03), 'R': np.float64(360.0), 'C': np.float64(236.97)}
# {'time-step': 21, 'O': np.float64(57.22), 'U': np.float64(0.6), 'L': np.float64(0.2188), 'P': np.float64(123.93), 'R': np.float64(360.0), 'C': np.float64(236.07)}
# {'time-step': 22, 'O': np.float64(74.34), 'U': np.float64(0.6), 'L': np.float64(0.2292), 'P': np.float64(124.52), 'R': np.float64(360.0), 'C': np.float64(235.48)}
# {'time-step': 23, 'O': np.float64(92.28), 'U': np.float64(0.6), 'L': np.float64(0.2396), 'P': np.float64(124.81), 'R': np.float64(360.0), 'C': np.float64(235.19)}
# {'time-step': 24, 'O': np.float64(111.0), 'U': np.float64(0.6), 'L': np.float64(0.25), 'P': np.float64(124.82), 'R': np.float64(360.0), 'C': np.float64(235.18)}
# {'time-step': 25, 'O': nan, 'U': nan, 'L': nan, 'P': nan, 'R': nan, 'C': nan}
# Average Utilization:  0.6
# CPU.S1|buy-dismiss|DC1,0.6-24 111.00189876515999 122.54401244769141
#                    action_string       score  real_score
# 0  CPU.S1|buy-dismiss|DC1,0.6-24  111.001899  122.544012

# %% [markdown]
# # buy-dismiss (using formula)

# %%
from utils import (load_problem_data,
                   load_solution)
from evaluation import evaluation_function, get_known, get_evaluation
import pandas as pd
import numpy as np

demand, datacenters, servers, selling_prices = load_problem_data(path='./data_test')

df_servers = pd.read_csv('./data/servers.csv')
df_datacenters = pd.read_csv('./data/datacenters.csv')
df_selling_price = pd.read_csv('./data/selling_prices.csv')

# %%
list_action_strings = []
for server_generation in df_servers['server_generation'].values:
    for datacenter_id in df_datacenters['datacenter_id'].values:
        for average_U in np.linspace(0.0, 1.0, 21)[1:]:
            life_expectancy = df_servers[df_servers['server_generation'] == server_generation]['life_expectancy'].iloc[0]
            for dismiss_age in range(life_expectancy, 0, -12):
                action_string = f"{server_generation}|buy-dismiss|{datacenter_id},{np.round(average_U,2)}-{dismiss_age}"
                list_action_strings.append(action_string)
len(list_action_strings)
# Out:
# 4480

# %%
df_results = []
# for action_string in ["CPU.S1|buy-dismiss|DC1,0.6-24"]:
for action_string in list_action_strings:
    action_comb = parse_action_string(action_string)

    server_generation = action_comb[0]["server_generation"]
    datacenter_id = action_comb[0]["datacenter_id"]

    df_cur_server = df_servers[df_servers['server_generation'] == server_generation]
    df_cur_datacenter = df_datacenters[df_datacenters['datacenter_id'] == datacenter_id]

    cost_of_energy = df_cur_datacenter['cost_of_energy'].iloc[0]
    latency_sensitivity = df_cur_datacenter['latency_sensitivity'].iloc[0]

    selling_price = df_selling_price[np.logical_and(df_selling_price['server_generation'] == server_generation, 
                                                    df_selling_price['latency_sensitivity'] == latency_sensitivity)]['selling_price'].iloc[0]


    life_expectancy = df_cur_server['life_expectancy'].iloc[0]
    purchase_price = df_cur_server['purchase_price'].iloc[0]
    energy_consumption_per_day = df_cur_server['energy_consumption'].iloc[0]
    energy_cost_per_day = energy_consumption_per_day * cost_of_energy
    average_mantainance_cost_per_day = df_cur_server['average_maintenance_fee'].iloc[0]
    server_capacity = df_cur_server['capacity'].iloc[0]
    dismiss_age = action_comb[1]["dismiss_age"]
    failure_rate = 0.07260491698699582
    failure_rate = 0.0
    average_U = action_comb[0]["average_U"]
    
    list_objective_per_day = []
    for i in range(1, dismiss_age+1):
        Z_fail = ((1-failure_rate) * server_capacity).astype(int)
        demand_met = np.minimum(Z_fail, average_U * server_capacity)
        U = demand_met / Z_fail
        L = i / life_expectancy
        R = demand_met * selling_price
        C = average_mantainance_cost_per_day * (1 + 1.5 * i / life_expectancy * np.log2(1.5 * i / life_expectancy)) + energy_cost_per_day
        if i == 1:
            C += purchase_price
        P = R - C
        list_objective_per_day.append([U, L, P])


    list_objective_per_day = np.asarray(list_objective_per_day)
    objective_per_day = list_objective_per_day[:,0]* list_objective_per_day[:,2]
    # objective_per_day = list_objective_per_day[:,0] * list_objective_per_day[:,1] * list_objective_per_day[:,2]
    total_objective = np.sum(objective_per_day)
    print(action_string, total_objective)
    df_results.append([action_string, total_objective])
# Out:
# CPU.S1|buy-dismiss|DC1,0.05-96 -2333.5178219457957
# CPU.S1|buy-dismiss|DC1,0.05-84 -1996.323911425124
# CPU.S1|buy-dismiss|DC1,0.05-72 -1718.783212901704
# CPU.S1|buy-dismiss|DC1,0.05-60 -1493.7079585770327
# CPU.S1|buy-dismiss|DC1,0.05-48 -1312.5932659255063
# CPU.S1|buy-dismiss|DC1,0.05-36 -1165.0184767182795
# CPU.S1|buy-dismiss|DC1,0.05-24 -1037.508365594626
# CPU.S1|buy-dismiss|DC1,0.05-12 -910.8782305224411
# CPU.S1|buy-dismiss|DC1,0.1-96 -4379.0356438915915
# CPU.S1|buy-dismiss|DC1,0.1-84 -3740.647822850248
# CPU.S1|buy-dismiss|DC1,0.1-72 -3221.566425803408
# CPU.S1|buy-dismiss|DC1,0.1-60 -2807.4159171540655
# CPU.S1|buy-dismiss|DC1,0.1-48 -2481.1865318510127
# CPU.S1|buy-dismiss|DC1,0.1-36 -2222.036953436559
# CPU.S1|buy-dismiss|DC1,0.1-24 -2003.016731189252
# CPU.S1|buy-dismiss|DC1,0.1-12 -1785.7564610448821
# CPU.S1|buy-dismiss|DC1,0.15-96 -6136.553465837387
# CPU.S1|buy-dismiss|DC1,0.15-84 -5232.971734275371
# CPU.S1|buy-dismiss|DC1,0.15-72 -4508.349638705111
# CPU.S1|buy-dismiss|DC1,0.15-60 -3941.123875731098
# CPU.S1|buy-dismiss|DC1,0.15-48 -3505.7797977765185
# CPU.S1|buy-dismiss|DC1,0.15-36 -3171.055430154838
# CPU.S1|buy-dismiss|DC1,0.15-24 -2896.5250967838774
# CPU.S1|buy-dismiss|DC1,0.15-12 -2624.634691567323
# CPU.S1|buy-dismiss|DC1,0.2-96 -7606.071287783182
# CPU.S1|buy-dismiss|DC1,0.2-84 -6473.295645700496
# CPU.S1|buy-dismiss|DC1,0.2-72 -5579.132851606816
# CPU.S1|buy-dismiss|DC1,0.2-60 -4894.831834308131
# CPU.S1|buy-dismiss|DC1,0.2-48 -4386.373063702025
# CPU.S1|buy-dismiss|DC1,0.2-36 -4012.073906873118
# CPU.S1|buy-dismiss|DC1,0.2-24 -3718.033462378504
# CPU.S1|buy-dismiss|DC1,0.2-12 -3427.5129220897643
# CPU.S1|buy-dismiss|DC1,0.25-96 -8787.589109728975
# CPU.S1|buy-dismiss|DC1,0.25-84 -7461.6195571256185
# CPU.S1|buy-dismiss|DC1,0.25-72 -6433.9160645085185
# CPU.S1|buy-dismiss|DC1,0.25-60 -5668.5397928851635
# CPU.S1|buy-dismiss|DC1,0.25-48 -5122.96632962753
# CPU.S1|buy-dismiss|DC1,0.25-36 -4745.092383591396
# CPU.S1|buy-dismiss|DC1,0.25-24 -4467.541827973129
# CPU.S1|buy-dismiss|DC1,0.25-12 -4194.391152612206
# CPU.S1|buy-dismiss|DC1,0.3-96 -9681.106931674774
# CPU.S1|buy-dismiss|DC1,0.3-84 -8197.943468550742
# CPU.S1|buy-dismiss|DC1,0.3-72 -7072.699277410222
# CPU.S1|buy-dismiss|DC1,0.3-60 -6262.247751462196
# CPU.S1|buy-dismiss|DC1,0.3-48 -5715.559595553037
# CPU.S1|buy-dismiss|DC1,0.3-36 -5370.110860309676
# CPU.S1|buy-dismiss|DC1,0.3-24 -5145.050193567755
# CPU.S1|buy-dismiss|DC1,0.3-12 -4925.269383134646
# CPU.S1|buy-dismiss|DC1,0.35-96 -10286.624753620566
# CPU.S1|buy-dismiss|DC1,0.35-84 -8682.267379975867
# CPU.S1|buy-dismiss|DC1,0.35-72 -7495.482490311926
# CPU.S1|buy-dismiss|DC1,0.35-60 -6675.9557100392285
# CPU.S1|buy-dismiss|DC1,0.35-48 -6164.152861478544
# CPU.S1|buy-dismiss|DC1,0.35-36 -5887.129337027955
# CPU.S1|buy-dismiss|DC1,0.35-24 -5750.558559162381
# CPU.S1|buy-dismiss|DC1,0.35-12 -5620.147613657088
# CPU.S1|buy-dismiss|DC1,0.4-96 -10604.142575566364
# CPU.S1|buy-dismiss|DC1,0.4-84 -8914.591291400991
# CPU.S1|buy-dismiss|DC1,0.4-72 -7702.265703213631
# CPU.S1|buy-dismiss|DC1,0.4-60 -6909.663668616263
# CPU.S1|buy-dismiss|DC1,0.4-48 -6468.746127404052
# CPU.S1|buy-dismiss|DC1,0.4-36 -6296.147813746236
# CPU.S1|buy-dismiss|DC1,0.4-24 -6284.066924757007
# CPU.S1|buy-dismiss|DC1,0.4-12 -6279.025844179529
# CPU.S1|buy-dismiss|DC1,0.45-96 -10633.660397512158
# CPU.S1|buy-dismiss|DC1,0.45-84 -8894.915202826114
# CPU.S1|buy-dismiss|DC1,0.45-72 -7693.048916115334
# CPU.S1|buy-dismiss|DC1,0.45-60 -6963.371627193293
# CPU.S1|buy-dismiss|DC1,0.45-48 -6629.339393329556
# CPU.S1|buy-dismiss|DC1,0.45-36 -6597.1662904645145
# CPU.S1|buy-dismiss|DC1,0.45-24 -6745.575290351633
# CPU.S1|buy-dismiss|DC1,0.45-12 -6901.904074701969
# CPU.S1|buy-dismiss|DC1,0.5-96 -10375.178219457952
# CPU.S1|buy-dismiss|DC1,0.5-84 -8623.239114251237
# CPU.S1|buy-dismiss|DC1,0.5-72 -7467.832129017037
# CPU.S1|buy-dismiss|DC1,0.5-60 -6837.079585770325
# CPU.S1|buy-dismiss|DC1,0.5-48 -6645.932659255062
# CPU.S1|buy-dismiss|DC1,0.5-36 -6790.184767182794
# CPU.S1|buy-dismiss|DC1,0.5-24 -7135.083655946259
# CPU.S1|buy-dismiss|DC1,0.5-12 -7488.782305224411
# CPU.S1|buy-dismiss|DC1,0.55-96 -9828.69604140375
# CPU.S1|buy-dismiss|DC1,0.55-84 -8099.563025676364
# CPU.S1|buy-dismiss|DC1,0.55-72 -7026.615341918742
# CPU.S1|buy-dismiss|DC1,0.55-60 -6530.787544347359
# CPU.S1|buy-dismiss|DC1,0.55-48 -6518.52592518057
# CPU.S1|buy-dismiss|DC1,0.55-36 -6875.2032439010745
# CPU.S1|buy-dismiss|DC1,0.55-24 -7452.592021540887
# CPU.S1|buy-dismiss|DC1,0.55-12 -8039.660535746852
# CPU.S1|buy-dismiss|DC1,0.6-96 -8994.213863349545
# CPU.S1|buy-dismiss|DC1,0.6-84 -7323.886937101485
# CPU.S1|buy-dismiss|DC1,0.6-72 -6369.398554820444
# CPU.S1|buy-dismiss|DC1,0.6-60 -6044.495502924389
# CPU.S1|buy-dismiss|DC1,0.6-48 -6247.119191106074
# CPU.S1|buy-dismiss|DC1,0.6-36 -6852.221720619351
# CPU.S1|buy-dismiss|DC1,0.6-24 -7698.100387135511
# CPU.S1|buy-dismiss|DC1,0.6-12 -8554.538766269292
# CPU.S1|buy-dismiss|DC1,0.65-96 -7871.731685295345
# CPU.S1|buy-dismiss|DC1,0.65-84 -6296.2108485266135
# CPU.S1|buy-dismiss|DC1,0.65-72 -5496.181767722152
# CPU.S1|buy-dismiss|DC1,0.65-60 -5378.203461501424
# CPU.S1|buy-dismiss|DC1,0.65-48 -5831.712457031583
# CPU.S1|buy-dismiss|DC1,0.65-36 -6721.240197337632
# CPU.S1|buy-dismiss|DC1,0.65-24 -7871.608752730136
# CPU.S1|buy-dismiss|DC1,0.65-12 -9033.416996791733
# CPU.S1|buy-dismiss|DC1,0.7-96 -6461.249507241136
# CPU.S1|buy-dismiss|DC1,0.7-84 -5016.534759951733
# CPU.S1|buy-dismiss|DC1,0.7-72 -4406.964980623854
# CPU.S1|buy-dismiss|DC1,0.7-60 -4531.911420078456
# CPU.S1|buy-dismiss|DC1,0.7-48 -5272.305722957086
# CPU.S1|buy-dismiss|DC1,0.7-36 -6482.258674055911
# CPU.S1|buy-dismiss|DC1,0.7-24 -7973.1171183247625
# CPU.S1|buy-dismiss|DC1,0.7-12 -9476.295227314176
# CPU.S1|buy-dismiss|DC1,0.75-96 -4762.767329186929
# CPU.S1|buy-dismiss|DC1,0.75-84 -3484.858671376857
# CPU.S1|buy-dismiss|DC1,0.75-72 -3101.748193525556
# CPU.S1|buy-dismiss|DC1,0.75-60 -3505.619378655488
# CPU.S1|buy-dismiss|DC1,0.75-48 -4568.898988882593
# CPU.S1|buy-dismiss|DC1,0.75-36 -6135.277150774191
# CPU.S1|buy-dismiss|DC1,0.75-24 -8002.625483919388
# CPU.S1|buy-dismiss|DC1,0.75-12 -9883.173457836616
# CPU.S1|buy-dismiss|DC1,0.8-96 -2776.2851511327262
# CPU.S1|buy-dismiss|DC1,0.8-84 -1701.1825828019812
# CPU.S1|buy-dismiss|DC1,0.8-72 -1580.5314064272616
# CPU.S1|buy-dismiss|DC1,0.8-60 -2299.3273372325243
# CPU.S1|buy-dismiss|DC1,0.8-48 -3721.4922548081013
# CPU.S1|buy-dismiss|DC1,0.8-36 -5680.295627492472
# CPU.S1|buy-dismiss|DC1,0.8-24 -7960.133849514014
# CPU.S1|buy-dismiss|DC1,0.8-12 -10254.051688359057
# CPU.S1|buy-dismiss|DC1,0.85-96 -501.8029730785238
# CPU.S1|buy-dismiss|DC1,0.85-84 334.4935057728926
# CPU.S1|buy-dismiss|DC1,0.85-72 156.6853806710351
# CPU.S1|buy-dismiss|DC1,0.85-60 -913.035295809554
# CPU.S1|buy-dismiss|DC1,0.85-48 -2730.0855207336062
# CPU.S1|buy-dismiss|DC1,0.85-36 -5117.314104210752
# CPU.S1|buy-dismiss|DC1,0.85-24 -7845.642215108643
# CPU.S1|buy-dismiss|DC1,0.85-12 -10588.929918881497
# CPU.S1|buy-dismiss|DC1,0.9-96 2060.679204975684
# CPU.S1|buy-dismiss|DC1,0.9-84 2622.169594347772
# CPU.S1|buy-dismiss|DC1,0.9-72 2109.9021677693327
# CPU.S1|buy-dismiss|DC1,0.9-60 653.2567456134154
# CPU.S1|buy-dismiss|DC1,0.9-48 -1594.6787866591103
# CPU.S1|buy-dismiss|DC1,0.9-36 -4446.332580929027
# CPU.S1|buy-dismiss|DC1,0.9-24 -7659.150580703266
# CPU.S1|buy-dismiss|DC1,0.9-12 -10887.808149403936
# CPU.S1|buy-dismiss|DC1,0.95-96 4911.161383029889
# CPU.S1|buy-dismiss|DC1,0.95-84 5161.845682922651
# CPU.S1|buy-dismiss|DC1,0.95-72 4279.11895486763
# CPU.S1|buy-dismiss|DC1,0.95-60 2399.5487870363845
# CPU.S1|buy-dismiss|DC1,0.95-48 -315.27205258461345
# CPU.S1|buy-dismiss|DC1,0.95-36 -3667.3510576473045
# CPU.S1|buy-dismiss|DC1,0.95-24 -7400.658946297889
# CPU.S1|buy-dismiss|DC1,0.95-12 -11150.686379926377
# CPU.S1|buy-dismiss|DC1,1.0-96 8049.643561084096
# CPU.S1|buy-dismiss|DC1,1.0-84 7953.521771497525
# CPU.S1|buy-dismiss|DC1,1.0-72 6664.335741965928
# CPU.S1|buy-dismiss|DC1,1.0-60 4325.840828459348
# CPU.S1|buy-dismiss|DC1,1.0-48 1108.1346814898761
# CPU.S1|buy-dismiss|DC1,1.0-36 -2780.3695343655854
# CPU.S1|buy-dismiss|DC1,1.0-24 -7070.167311892516
# CPU.S1|buy-dismiss|DC1,1.0-12 -11377.564610448822
# CPU.S1|buy-dismiss|DC2,0.05-96 -2453.5178219457957
# CPU.S1|buy-dismiss|DC2,0.05-84 -2101.323911425124
# CPU.S1|buy-dismiss|DC2,0.05-72 -1808.783212901704
# CPU.S1|buy-dismiss|DC2,0.05-60 -1568.7079585770327
# CPU.S1|buy-dismiss|DC2,0.05-48 -1372.5932659255063
# CPU.S1|buy-dismiss|DC2,0.05-36 -1210.0184767182795
# CPU.S1|buy-dismiss|DC2,0.05-24 -1067.508365594626
# CPU.S1|buy-dismiss|DC2,0.05-12 -925.8782305224411
# CPU.S1|buy-dismiss|DC2,0.1-96 -4475.0356438915915
# CPU.S1|buy-dismiss|DC2,0.1-84 -3824.647822850248
# CPU.S1|buy-dismiss|DC2,0.1-72 -3293.566425803408
# CPU.S1|buy-dismiss|DC2,0.1-60 -2867.4159171540655
# CPU.S1|buy-dismiss|DC2,0.1-48 -2529.1865318510127
# CPU.S1|buy-dismiss|DC2,0.1-36 -2258.036953436559
# CPU.S1|buy-dismiss|DC2,0.1-24 -2027.016731189252
# CPU.S1|buy-dismiss|DC2,0.1-12 -1797.7564610448821
# CPU.S1|buy-dismiss|DC2,0.15-96 -6064.553465837385
# CPU.S1|buy-dismiss|DC2,0.15-84 -5169.971734275371
# CPU.S1|buy-dismiss|DC2,0.15-72 -4454.349638705111
# CPU.S1|buy-dismiss|DC2,0.15-60 -3896.123875731098
# CPU.S1|buy-dismiss|DC2,0.15-48 -3469.7797977765185
# CPU.S1|buy-dismiss|DC2,0.15-36 -3144.055430154838
# CPU.S1|buy-dismiss|DC2,0.15-24 -2878.5250967838774
# CPU.S1|buy-dismiss|DC2,0.15-12 -2615.634691567323
# CPU.S1|buy-dismiss|DC2,0.2-96 -7222.071287783182
# CPU.S1|buy-dismiss|DC2,0.2-84 -6137.295645700496
# CPU.S1|buy-dismiss|DC2,0.2-72 -5291.132851606816
# CPU.S1|buy-dismiss|DC2,0.2-60 -4654.831834308131
# CPU.S1|buy-dismiss|DC2,0.2-48 -4194.373063702025
# CPU.S1|buy-dismiss|DC2,0.2-36 -3868.073906873118
# CPU.S1|buy-dismiss|DC2,0.2-24 -3622.033462378504
# CPU.S1|buy-dismiss|DC2,0.2-12 -3379.5129220897643
# CPU.S1|buy-dismiss|DC2,0.25-96 -7947.589109728976
# CPU.S1|buy-dismiss|DC2,0.25-84 -6726.6195571256185
# CPU.S1|buy-dismiss|DC2,0.25-72 -5803.9160645085185
# CPU.S1|buy-dismiss|DC2,0.25-60 -5143.5397928851635
# CPU.S1|buy-dismiss|DC2,0.25-48 -4702.96632962753
# CPU.S1|buy-dismiss|DC2,0.25-36 -4430.092383591396
# CPU.S1|buy-dismiss|DC2,0.25-24 -4257.541827973129
# CPU.S1|buy-dismiss|DC2,0.25-12 -4089.3911526122056
# CPU.S1|buy-dismiss|DC2,0.3-96 -8241.106931674773
# CPU.S1|buy-dismiss|DC2,0.3-84 -6937.943468550743
# CPU.S1|buy-dismiss|DC2,0.3-72 -5992.699277410222
# CPU.S1|buy-dismiss|DC2,0.3-60 -5362.247751462196
# CPU.S1|buy-dismiss|DC2,0.3-48 -4995.559595553037
# CPU.S1|buy-dismiss|DC2,0.3-36 -4830.110860309676
# CPU.S1|buy-dismiss|DC2,0.3-24 -4785.050193567755
# CPU.S1|buy-dismiss|DC2,0.3-12 -4745.269383134646
# CPU.S1|buy-dismiss|DC2,0.35-96 -8102.6247536205665
# CPU.S1|buy-dismiss|DC2,0.35-84 -6771.267379975868
# CPU.S1|buy-dismiss|DC2,0.35-72 -5857.482490311926
# CPU.S1|buy-dismiss|DC2,0.35-60 -5310.9557100392285
# CPU.S1|buy-dismiss|DC2,0.35-48 -5072.152861478544
# CPU.S1|buy-dismiss|DC2,0.35-36 -5068.129337027955
# CPU.S1|buy-dismiss|DC2,0.35-24 -5204.558559162381
# CPU.S1|buy-dismiss|DC2,0.35-12 -5347.147613657088
# CPU.S1|buy-dismiss|DC2,0.4-96 -7532.142575566364
# CPU.S1|buy-dismiss|DC2,0.4-84 -6226.59129140099
# CPU.S1|buy-dismiss|DC2,0.4-72 -5398.265703213631
# CPU.S1|buy-dismiss|DC2,0.4-60 -4989.663668616263
# CPU.S1|buy-dismiss|DC2,0.4-48 -4932.746127404052
# CPU.S1|buy-dismiss|DC2,0.4-36 -5144.147813746236
# CPU.S1|buy-dismiss|DC2,0.4-24 -5516.066924757007
# CPU.S1|buy-dismiss|DC2,0.4-12 -5895.025844179529
# CPU.S1|buy-dismiss|DC2,0.45-96 -6529.660397512158
# CPU.S1|buy-dismiss|DC2,0.45-84 -5303.915202826114
# CPU.S1|buy-dismiss|DC2,0.45-72 -4615.048916115335
# CPU.S1|buy-dismiss|DC2,0.45-60 -4398.371627193293
# CPU.S1|buy-dismiss|DC2,0.45-48 -4577.339393329556
# CPU.S1|buy-dismiss|DC2,0.45-36 -5058.1662904645145
# CPU.S1|buy-dismiss|DC2,0.45-24 -5719.575290351633
# CPU.S1|buy-dismiss|DC2,0.45-12 -6388.904074701969
# CPU.S1|buy-dismiss|DC2,0.5-96 -5095.178219457952
# CPU.S1|buy-dismiss|DC2,0.5-84 -4003.2391142512374
# CPU.S1|buy-dismiss|DC2,0.5-72 -3507.8321290170366
# CPU.S1|buy-dismiss|DC2,0.5-60 -3537.0795857703256
# CPU.S1|buy-dismiss|DC2,0.5-48 -4005.9326592550624
# CPU.S1|buy-dismiss|DC2,0.5-36 -4810.184767182794
# CPU.S1|buy-dismiss|DC2,0.5-24 -5815.083655946259
# CPU.S1|buy-dismiss|DC2,0.5-12 -6828.782305224411
# CPU.S1|buy-dismiss|DC2,0.55-96 -3228.6960414037494
# CPU.S1|buy-dismiss|DC2,0.55-84 -2324.563025676363
# CPU.S1|buy-dismiss|DC2,0.55-72 -2076.615341918741
# CPU.S1|buy-dismiss|DC2,0.55-60 -2405.787544347358
# CPU.S1|buy-dismiss|DC2,0.55-48 -3218.525925180569
# CPU.S1|buy-dismiss|DC2,0.55-36 -4400.203243901074
# CPU.S1|buy-dismiss|DC2,0.55-24 -5802.592021540886
# CPU.S1|buy-dismiss|DC2,0.55-12 -7214.660535746852
# CPU.S1|buy-dismiss|DC2,0.6-96 -930.2138633495442
# CPU.S1|buy-dismiss|DC2,0.6-84 -267.8869371014854
# CPU.S1|buy-dismiss|DC2,0.6-72 -321.3985548204455
# CPU.S1|buy-dismiss|DC2,0.6-60 -1004.4955029243911
# CPU.S1|buy-dismiss|DC2,0.6-48 -2215.119191106074
# CPU.S1|buy-dismiss|DC2,0.6-36 -3828.221720619353
# CPU.S1|buy-dismiss|DC2,0.6-24 -5682.100387135511
# CPU.S1|buy-dismiss|DC2,0.6-12 -7546.538766269291
# CPU.S1|buy-dismiss|DC2,0.65-96 1800.2683147046564
# CPU.S1|buy-dismiss|DC2,0.65-84 2166.7891514733883
# CPU.S1|buy-dismiss|DC2,0.65-72 1757.8182322778484
# CPU.S1|buy-dismiss|DC2,0.65-60 666.7965384985762
# CPU.S1|buy-dismiss|DC2,0.65-48 -995.7124570315818
# CPU.S1|buy-dismiss|DC2,0.65-36 -3094.240197337632
# CPU.S1|buy-dismiss|DC2,0.65-24 -5453.608752730137
# CPU.S1|buy-dismiss|DC2,0.65-12 -7824.416996791733
# CPU.S1|buy-dismiss|DC2,0.7-96 4962.750492758863
# CPU.S1|buy-dismiss|DC2,0.7-84 4979.465240048266
# CPU.S1|buy-dismiss|DC2,0.7-72 4161.035019376147
# CPU.S1|buy-dismiss|DC2,0.7-60 2608.0885799215434
# CPU.S1|buy-dismiss|DC2,0.7-48 439.6942770429132
# CPU.S1|buy-dismiss|DC2,0.7-36 -2198.2586740559113
# CPU.S1|buy-dismiss|DC2,0.7-24 -5117.1171183247625
# CPU.S1|buy-dismiss|DC2,0.7-12 -8048.295227314176
# CPU.S1|buy-dismiss|DC2,0.75-96 8557.232670813073
# CPU.S1|buy-dismiss|DC2,0.75-84 8170.141328623143
# CPU.S1|buy-dismiss|DC2,0.75-72 6888.251806474445
# CPU.S1|buy-dismiss|DC2,0.75-60 4819.380621344511
# CPU.S1|buy-dismiss|DC2,0.75-48 2091.1010111174073
# CPU.S1|buy-dismiss|DC2,0.75-36 -1140.2771507741895
# CPU.S1|buy-dismiss|DC2,0.75-24 -4672.625483919388
# CPU.S1|buy-dismiss|DC2,0.75-12 -8218.173457836616
# CPU.S1|buy-dismiss|DC2,0.8-96 12583.714848867272
# CPU.S1|buy-dismiss|DC2,0.8-84 11738.817417198019
# CPU.S1|buy-dismiss|DC2,0.8-72 9939.468593572738
# CPU.S1|buy-dismiss|DC2,0.8-60 7300.672662767477
# CPU.S1|buy-dismiss|DC2,0.8-48 3958.5077451918987
# CPU.S1|buy-dismiss|DC2,0.8-36 79.70437250752946
# CPU.S1|buy-dismiss|DC2,0.8-24 -4120.133849514014
# CPU.S1|buy-dismiss|DC2,0.8-12 -8334.051688359057
# CPU.S1|buy-dismiss|DC2,0.85-96 17042.197026921476
# CPU.S1|buy-dismiss|DC2,0.85-84 15685.493505772893
# CPU.S1|buy-dismiss|DC2,0.85-72 13314.685380671031
# CPU.S1|buy-dismiss|DC2,0.85-60 10051.964704190446
# CPU.S1|buy-dismiss|DC2,0.85-48 6041.914479266393
# CPU.S1|buy-dismiss|DC2,0.85-36 1461.6858957892484
# CPU.S1|buy-dismiss|DC2,0.85-24 -3459.6422151086426
# CPU.S1|buy-dismiss|DC2,0.85-12 -8395.929918881497
# CPU.S1|buy-dismiss|DC2,0.9-96 21932.679204975688
# CPU.S1|buy-dismiss|DC2,0.9-84 20010.169594347775
# CPU.S1|buy-dismiss|DC2,0.9-72 17013.90216776933
# CPU.S1|buy-dismiss|DC2,0.9-60 13073.256745613417
# CPU.S1|buy-dismiss|DC2,0.9-48 8341.321213340889
# CPU.S1|buy-dismiss|DC2,0.9-36 3005.667419070974
# CPU.S1|buy-dismiss|DC2,0.9-24 -2691.1505807032645
# CPU.S1|buy-dismiss|DC2,0.9-12 -8403.808149403936
# CPU.S1|buy-dismiss|DC2,0.95-96 27255.16138302989
# CPU.S1|buy-dismiss|DC2,0.95-84 24712.84568292265
# CPU.S1|buy-dismiss|DC2,0.95-72 21037.11895486763
# CPU.S1|buy-dismiss|DC2,0.95-60 16364.548787036385
# CPU.S1|buy-dismiss|DC2,0.95-48 10856.727947415384
# CPU.S1|buy-dismiss|DC2,0.95-36 4711.648942352695
# CPU.S1|buy-dismiss|DC2,0.95-24 -1814.658946297889
# CPU.S1|buy-dismiss|DC2,0.95-12 -8357.686379926381
# CPU.S1|buy-dismiss|DC2,1.0-96 33009.6435610841
# CPU.S1|buy-dismiss|DC2,1.0-84 29793.521771497526
# CPU.S1|buy-dismiss|DC2,1.0-72 25384.335741965926
# CPU.S1|buy-dismiss|DC2,1.0-60 19925.84082845935
# CPU.S1|buy-dismiss|DC2,1.0-48 13588.134681489877
# CPU.S1|buy-dismiss|DC2,1.0-36 6579.630465634415
# CPU.S1|buy-dismiss|DC2,1.0-24 -830.1673118925173
# CPU.S1|buy-dismiss|DC2,1.0-12 -8257.564610448822
# CPU.S1|buy-dismiss|DC3,0.05-96 -2885.5178219457957
# CPU.S1|buy-dismiss|DC3,0.05-84 -2479.3239114251246
# CPU.S1|buy-dismiss|DC3,0.05-72 -2132.7832129017042
# CPU.S1|buy-dismiss|DC3,0.05-60 -1838.7079585770327
# CPU.S1|buy-dismiss|DC3,0.05-48 -1588.5932659255063
# CPU.S1|buy-dismiss|DC3,0.05-36 -1372.0184767182795
# CPU.S1|buy-dismiss|DC3,0.05-24 -1175.508365594626
# CPU.S1|buy-dismiss|DC3,0.05-12 -979.8782305224411
# CPU.S1|buy-dismiss|DC3,0.1-96 -5051.0356438915915
# CPU.S1|buy-dismiss|DC3,0.1-84 -4328.647822850248
# CPU.S1|buy-dismiss|DC3,0.1-72 -3725.566425803408
# CPU.S1|buy-dismiss|DC3,0.1-60 -3227.4159171540655
# CPU.S1|buy-dismiss|DC3,0.1-48 -2817.1865318510127
# CPU.S1|buy-dismiss|DC3,0.1-36 -2474.036953436559
# CPU.S1|buy-dismiss|DC3,0.1-24 -2171.016731189252
# CPU.S1|buy-dismiss|DC3,0.1-12 -1869.7564610448821
# CPU.S1|buy-dismiss|DC3,0.15-96 -6496.553465837387
# CPU.S1|buy-dismiss|DC3,0.15-84 -5547.971734275371
# CPU.S1|buy-dismiss|DC3,0.15-72 -4778.349638705111
# CPU.S1|buy-dismiss|DC3,0.15-60 -4166.1238757310975
# CPU.S1|buy-dismiss|DC3,0.15-48 -3685.7797977765185
# CPU.S1|buy-dismiss|DC3,0.15-36 -3306.055430154838
# CPU.S1|buy-dismiss|DC3,0.15-24 -2986.5250967838774
# CPU.S1|buy-dismiss|DC3,0.15-12 -2669.634691567323
# CPU.S1|buy-dismiss|DC3,0.2-96 -7222.071287783182
# CPU.S1|buy-dismiss|DC3,0.2-84 -6137.295645700496
# CPU.S1|buy-dismiss|DC3,0.2-72 -5291.132851606816
# CPU.S1|buy-dismiss|DC3,0.2-60 -4654.831834308131
# CPU.S1|buy-dismiss|DC3,0.2-48 -4194.373063702025
# CPU.S1|buy-dismiss|DC3,0.2-36 -3868.073906873118
# CPU.S1|buy-dismiss|DC3,0.2-24 -3622.033462378504
# CPU.S1|buy-dismiss|DC3,0.2-12 -3379.5129220897643
# CPU.S1|buy-dismiss|DC3,0.25-96 -7227.589109728976
# CPU.S1|buy-dismiss|DC3,0.25-84 -6096.6195571256185
# CPU.S1|buy-dismiss|DC3,0.25-72 -5263.9160645085185
# CPU.S1|buy-dismiss|DC3,0.25-60 -4693.5397928851635
# CPU.S1|buy-dismiss|DC3,0.25-48 -4342.966329627531
# CPU.S1|buy-dismiss|DC3,0.25-36 -4160.092383591396
# CPU.S1|buy-dismiss|DC3,0.25-24 -4077.5418279731293
# CPU.S1|buy-dismiss|DC3,0.25-12 -3999.3911526122056
# CPU.S1|buy-dismiss|DC3,0.3-96 -6513.1069316747735
# CPU.S1|buy-dismiss|DC3,0.3-84 -5425.943468550744
# CPU.S1|buy-dismiss|DC3,0.3-72 -4696.699277410222
# CPU.S1|buy-dismiss|DC3,0.3-60 -4282.247751462196
# CPU.S1|buy-dismiss|DC3,0.3-48 -4131.559595553037
# CPU.S1|buy-dismiss|DC3,0.3-36 -4182.110860309676
# CPU.S1|buy-dismiss|DC3,0.3-24 -4353.050193567755
# CPU.S1|buy-dismiss|DC3,0.3-12 -4529.269383134646
# CPU.S1|buy-dismiss|DC3,0.35-96 -5078.624753620567
# CPU.S1|buy-dismiss|DC3,0.35-84 -4125.267379975867
# CPU.S1|buy-dismiss|DC3,0.35-72 -3589.482490311927
# CPU.S1|buy-dismiss|DC3,0.35-60 -3420.9557100392276
# CPU.S1|buy-dismiss|DC3,0.35-48 -3560.152861478544
# CPU.S1|buy-dismiss|DC3,0.35-36 -3934.1293370279554
# CPU.S1|buy-dismiss|DC3,0.35-24 -4448.558559162381
# CPU.S1|buy-dismiss|DC3,0.35-12 -4969.147613657088
# CPU.S1|buy-dismiss|DC3,0.4-96 -2924.1425755663636
# CPU.S1|buy-dismiss|DC3,0.4-84 -2194.591291400991
# CPU.S1|buy-dismiss|DC3,0.4-72 -1942.2657032136308
# CPU.S1|buy-dismiss|DC3,0.4-60 -2109.6636686162606
# CPU.S1|buy-dismiss|DC3,0.4-48 -2628.746127404051
# CPU.S1|buy-dismiss|DC3,0.4-36 -3416.147813746236
# CPU.S1|buy-dismiss|DC3,0.4-24 -4364.066924757007
# CPU.S1|buy-dismiss|DC3,0.4-12 -5319.025844179529
# CPU.S1|buy-dismiss|DC3,0.45-96 -49.66039751215794
# CPU.S1|buy-dismiss|DC3,0.45-84 366.08479717388553
# CPU.S1|buy-dismiss|DC3,0.45-72 244.9510838846668
# CPU.S1|buy-dismiss|DC3,0.45-60 -348.37162719329274
# CPU.S1|buy-dismiss|DC3,0.45-48 -1337.3393933295547
# CPU.S1|buy-dismiss|DC3,0.45-36 -2628.166290464514
# CPU.S1|buy-dismiss|DC3,0.45-24 -4099.575290351633
# CPU.S1|buy-dismiss|DC3,0.45-12 -5578.904074701968
# CPU.S1|buy-dismiss|DC3,0.5-96 3544.821780542048
# CPU.S1|buy-dismiss|DC3,0.5-84 3556.7608857487626
# CPU.S1|buy-dismiss|DC3,0.5-72 2972.167870982964
# CPU.S1|buy-dismiss|DC3,0.5-60 1862.9204142296737
# CPU.S1|buy-dismiss|DC3,0.5-48 314.06734074493806
# CPU.S1|buy-dismiss|DC3,0.5-36 -1570.1847671827927
# CPU.S1|buy-dismiss|DC3,0.5-24 -3655.083655946258
# CPU.S1|buy-dismiss|DC3,0.5-12 -5748.782305224411
# CPU.S1|buy-dismiss|DC3,0.55-96 7859.303958596251
# CPU.S1|buy-dismiss|DC3,0.55-84 7377.436974323638
# CPU.S1|buy-dismiss|DC3,0.55-72 6239.38465808126
# CPU.S1|buy-dismiss|DC3,0.55-60 4524.212455652642
# CPU.S1|buy-dismiss|DC3,0.55-48 2325.474074819431
# CPU.S1|buy-dismiss|DC3,0.55-36 -242.20324390107396
# CPU.S1|buy-dismiss|DC3,0.55-24 -3030.592021540886
# CPU.S1|buy-dismiss|DC3,0.55-12 -5828.660535746852
# CPU.S1|buy-dismiss|DC3,0.6-96 12893.786136650453
# CPU.S1|buy-dismiss|DC3,0.6-84 11828.113062898512
# CPU.S1|buy-dismiss|DC3,0.6-72 10046.601445179555
# CPU.S1|buy-dismiss|DC3,0.6-60 7635.504497075609
# CPU.S1|buy-dismiss|DC3,0.6-48 4696.880808893924
# CPU.S1|buy-dismiss|DC3,0.6-36 1355.778279380646
# CPU.S1|buy-dismiss|DC3,0.6-24 -2226.1003871355115
# CPU.S1|buy-dismiss|DC3,0.6-12 -5818.538766269292
# CPU.S1|buy-dismiss|DC3,0.65-96 18648.268314704663
# CPU.S1|buy-dismiss|DC3,0.65-84 16908.78915147339
# CPU.S1|buy-dismiss|DC3,0.65-72 14393.818232277852
# CPU.S1|buy-dismiss|DC3,0.65-60 11196.796538498578
# CPU.S1|buy-dismiss|DC3,0.65-48 7428.28754296842
# CPU.S1|buy-dismiss|DC3,0.65-36 3223.759802662368
# CPU.S1|buy-dismiss|DC3,0.65-24 -1241.608752730136
# CPU.S1|buy-dismiss|DC3,0.65-12 -5718.416996791734
# CPU.S1|buy-dismiss|DC3,0.7-96 25122.750492758863
# CPU.S1|buy-dismiss|DC3,0.7-84 22619.465240048266
# CPU.S1|buy-dismiss|DC3,0.7-72 19281.035019376148
# CPU.S1|buy-dismiss|DC3,0.7-60 15208.088579921541
# CPU.S1|buy-dismiss|DC3,0.7-48 10519.69427704291
# CPU.S1|buy-dismiss|DC3,0.7-36 5361.741325944086
# CPU.S1|buy-dismiss|DC3,0.7-24 -77.11711832476249
# CPU.S1|buy-dismiss|DC3,0.7-12 -5528.295227314175
# CPU.S1|buy-dismiss|DC3,0.75-96 32317.232670813068
# CPU.S1|buy-dismiss|DC3,0.75-84 28960.14132862314
# CPU.S1|buy-dismiss|DC3,0.75-72 24708.251806474444
# CPU.S1|buy-dismiss|DC3,0.75-60 19669.380621344513
# CPU.S1|buy-dismiss|DC3,0.75-48 13971.101011117407
# CPU.S1|buy-dismiss|DC3,0.75-36 7769.722849225809
# CPU.S1|buy-dismiss|DC3,0.75-24 1267.374516080612
# CPU.S1|buy-dismiss|DC3,0.75-12 -5248.173457836616
# CPU.S1|buy-dismiss|DC3,0.8-96 40231.714848867276
# CPU.S1|buy-dismiss|DC3,0.8-84 35930.81741719802
# CPU.S1|buy-dismiss|DC3,0.8-72 30675.468593572743
# CPU.S1|buy-dismiss|DC3,0.8-60 24580.672662767476
# CPU.S1|buy-dismiss|DC3,0.8-48 17782.5077451919
# CPU.S1|buy-dismiss|DC3,0.8-36 10447.704372507531
# CPU.S1|buy-dismiss|DC3,0.8-24 2791.8661504859865
# CPU.S1|buy-dismiss|DC3,0.8-12 -4878.051688359057
# CPU.S1|buy-dismiss|DC3,0.85-96 48866.19702692148
# CPU.S1|buy-dismiss|DC3,0.85-84 43531.493505772894
# CPU.S1|buy-dismiss|DC3,0.85-72 37182.685380671035
# CPU.S1|buy-dismiss|DC3,0.85-60 29941.964704190443
# CPU.S1|buy-dismiss|DC3,0.85-48 21953.914479266397
# CPU.S1|buy-dismiss|DC3,0.85-36 13395.685895789251
# CPU.S1|buy-dismiss|DC3,0.85-24 4496.357784891358
# CPU.S1|buy-dismiss|DC3,0.85-12 -4417.929918881497
# CPU.S1|buy-dismiss|DC3,0.9-96 58220.679204975684
# CPU.S1|buy-dismiss|DC3,0.9-84 51762.169594347775
# CPU.S1|buy-dismiss|DC3,0.9-72 44229.90216776934
# CPU.S1|buy-dismiss|DC3,0.9-60 35753.25674561342
# CPU.S1|buy-dismiss|DC3,0.9-48 26485.321213340892
# CPU.S1|buy-dismiss|DC3,0.9-36 16613.667419070975
# CPU.S1|buy-dismiss|DC3,0.9-24 6380.849419296735
# CPU.S1|buy-dismiss|DC3,0.9-12 -3867.808149403938
# CPU.S1|buy-dismiss|DC3,0.95-96 68295.16138302989
# CPU.S1|buy-dismiss|DC3,0.95-84 60622.84568292265
# CPU.S1|buy-dismiss|DC3,0.95-72 51817.118954867634
# CPU.S1|buy-dismiss|DC3,0.95-60 42014.54878703638
# CPU.S1|buy-dismiss|DC3,0.95-48 31376.727947415384
# CPU.S1|buy-dismiss|DC3,0.95-36 20101.648942352695
# CPU.S1|buy-dismiss|DC3,0.95-24 8445.34105370211
# CPU.S1|buy-dismiss|DC3,0.95-12 -3227.68637992638
# CPU.S1|buy-dismiss|DC3,1.0-96 79089.64356108409
# CPU.S1|buy-dismiss|DC3,1.0-84 70113.5217714975
# CPU.S1|buy-dismiss|DC3,1.0-72 59944.33574196593
# CPU.S1|buy-dismiss|DC3,1.0-60 48725.84082845934
# CPU.S1|buy-dismiss|DC3,1.0-48 36628.13468148987
# CPU.S1|buy-dismiss|DC3,1.0-36 23859.630465634415
# CPU.S1|buy-dismiss|DC3,1.0-24 10689.832688107483
# CPU.S1|buy-dismiss|DC3,1.0-12 -2497.5646104488205
# CPU.S1|buy-dismiss|DC4,0.05-96 -3077.5178219457957
# CPU.S1|buy-dismiss|DC4,0.05-84 -2647.3239114251246
# CPU.S1|buy-dismiss|DC4,0.05-72 -2276.7832129017042
# CPU.S1|buy-dismiss|DC4,0.05-60 -1958.7079585770327
# CPU.S1|buy-dismiss|DC4,0.05-48 -1684.5932659255063
# CPU.S1|buy-dismiss|DC4,0.05-36 -1444.0184767182795
# CPU.S1|buy-dismiss|DC4,0.05-24 -1223.508365594626
# CPU.S1|buy-dismiss|DC4,0.05-12 -1003.8782305224411
# CPU.S1|buy-dismiss|DC4,0.1-96 -5435.0356438915915
# CPU.S1|buy-dismiss|DC4,0.1-84 -4664.647822850248
# CPU.S1|buy-dismiss|DC4,0.1-72 -4013.566425803408
# CPU.S1|buy-dismiss|DC4,0.1-60 -3467.4159171540655
# CPU.S1|buy-dismiss|DC4,0.1-48 -3009.1865318510127
# CPU.S1|buy-dismiss|DC4,0.1-36 -2618.036953436559
# CPU.S1|buy-dismiss|DC4,0.1-24 -2267.016731189252
# CPU.S1|buy-dismiss|DC4,0.1-12 -1917.7564610448821
# CPU.S1|buy-dismiss|DC4,0.15-96 -7072.553465837387
# CPU.S1|buy-dismiss|DC4,0.15-84 -6051.971734275371
# CPU.S1|buy-dismiss|DC4,0.15-72 -5210.349638705111
# CPU.S1|buy-dismiss|DC4,0.15-60 -4526.1238757310975
# CPU.S1|buy-dismiss|DC4,0.15-48 -3973.7797977765185
# CPU.S1|buy-dismiss|DC4,0.15-36 -3522.055430154838
# CPU.S1|buy-dismiss|DC4,0.15-24 -3130.5250967838774
# CPU.S1|buy-dismiss|DC4,0.15-12 -2741.634691567323
# CPU.S1|buy-dismiss|DC4,0.2-96 -7990.071287783182
# CPU.S1|buy-dismiss|DC4,0.2-84 -6809.295645700496
# CPU.S1|buy-dismiss|DC4,0.2-72 -5867.132851606816
# CPU.S1|buy-dismiss|DC4,0.2-60 -5134.831834308131
# CPU.S1|buy-dismiss|DC4,0.2-48 -4578.373063702025
# CPU.S1|buy-dismiss|DC4,0.2-36 -4156.073906873118
# CPU.S1|buy-dismiss|DC4,0.2-24 -3814.033462378504
# CPU.S1|buy-dismiss|DC4,0.2-12 -3475.5129220897643
# CPU.S1|buy-dismiss|DC4,0.25-96 -8187.589109728976
# CPU.S1|buy-dismiss|DC4,0.25-84 -6936.6195571256185
# CPU.S1|buy-dismiss|DC4,0.25-72 -5983.916064508519
# CPU.S1|buy-dismiss|DC4,0.25-60 -5293.5397928851635
# CPU.S1|buy-dismiss|DC4,0.25-48 -4822.96632962753
# CPU.S1|buy-dismiss|DC4,0.25-36 -4520.092383591396
# CPU.S1|buy-dismiss|DC4,0.25-24 -4317.541827973129
# CPU.S1|buy-dismiss|DC4,0.25-12 -4119.391152612206
# CPU.S1|buy-dismiss|DC4,0.3-96 -7665.1069316747735
# CPU.S1|buy-dismiss|DC4,0.3-84 -6433.943468550744
# CPU.S1|buy-dismiss|DC4,0.3-72 -5560.699277410222
# CPU.S1|buy-dismiss|DC4,0.3-60 -5002.247751462196
# CPU.S1|buy-dismiss|DC4,0.3-48 -4707.559595553037
# CPU.S1|buy-dismiss|DC4,0.3-36 -4614.110860309676
# CPU.S1|buy-dismiss|DC4,0.3-24 -4641.050193567755
# CPU.S1|buy-dismiss|DC4,0.3-12 -4673.269383134646
# CPU.S1|buy-dismiss|DC4,0.35-96 -6422.624753620568
# CPU.S1|buy-dismiss|DC4,0.35-84 -5301.267379975868
# CPU.S1|buy-dismiss|DC4,0.35-72 -4597.482490311926
# CPU.S1|buy-dismiss|DC4,0.35-60 -4260.9557100392285
# CPU.S1|buy-dismiss|DC4,0.35-48 -4232.152861478544
# CPU.S1|buy-dismiss|DC4,0.35-36 -4438.129337027955
# CPU.S1|buy-dismiss|DC4,0.35-24 -4784.558559162381
# CPU.S1|buy-dismiss|DC4,0.35-12 -5137.147613657088
# CPU.S1|buy-dismiss|DC4,0.4-96 -4460.142575566364
# CPU.S1|buy-dismiss|DC4,0.4-84 -3538.591291400991
# CPU.S1|buy-dismiss|DC4,0.4-72 -3094.2657032136312
# CPU.S1|buy-dismiss|DC4,0.4-60 -3069.6636686162606
# CPU.S1|buy-dismiss|DC4,0.4-48 -3396.746127404051
# CPU.S1|buy-dismiss|DC4,0.4-36 -3992.1478137462354
# CPU.S1|buy-dismiss|DC4,0.4-24 -4748.066924757007
# CPU.S1|buy-dismiss|DC4,0.4-12 -5511.025844179529
# CPU.S1|buy-dismiss|DC4,0.45-96 -1777.6603975121575
# CPU.S1|buy-dismiss|DC4,0.45-84 -1145.915202826114
# CPU.S1|buy-dismiss|DC4,0.45-72 -1051.0489161153332
# CPU.S1|buy-dismiss|DC4,0.45-60 -1428.3716271932929
# CPU.S1|buy-dismiss|DC4,0.45-48 -2201.339393329555
# CPU.S1|buy-dismiss|DC4,0.45-36 -3276.166290464514
# CPU.S1|buy-dismiss|DC4,0.45-24 -4531.575290351632
# CPU.S1|buy-dismiss|DC4,0.45-12 -5794.904074701968
# CPU.S1|buy-dismiss|DC4,0.5-96 1624.8217805420463
# CPU.S1|buy-dismiss|DC4,0.5-84 1876.7608857487617
# CPU.S1|buy-dismiss|DC4,0.5-72 1532.167870982963
# CPU.S1|buy-dismiss|DC4,0.5-60 662.9204142296742
# CPU.S1|buy-dismiss|DC4,0.5-48 -645.9326592550619
# CPU.S1|buy-dismiss|DC4,0.5-36 -2290.1847671827927
# CPU.S1|buy-dismiss|DC4,0.5-24 -4135.083655946259
# CPU.S1|buy-dismiss|DC4,0.5-12 -5988.782305224411
# CPU.S1|buy-dismiss|DC4,0.55-96 5747.303958596251
# CPU.S1|buy-dismiss|DC4,0.55-84 5529.436974323637
# CPU.S1|buy-dismiss|DC4,0.55-72 4655.384658081259
# CPU.S1|buy-dismiss|DC4,0.55-60 3204.2124556526423
# CPU.S1|buy-dismiss|DC4,0.55-48 1269.4740748194308
# CPU.S1|buy-dismiss|DC4,0.55-36 -1034.203243901074
# CPU.S1|buy-dismiss|DC4,0.55-24 -3558.592021540886
# CPU.S1|buy-dismiss|DC4,0.55-12 -6092.660535746852
# CPU.S1|buy-dismiss|DC4,0.6-96 10589.786136650453
# CPU.S1|buy-dismiss|DC4,0.6-84 9812.113062898512
# CPU.S1|buy-dismiss|DC4,0.6-72 8318.601445179555
# CPU.S1|buy-dismiss|DC4,0.6-60 6195.504497075609
# CPU.S1|buy-dismiss|DC4,0.6-48 3544.880808893924
# CPU.S1|buy-dismiss|DC4,0.6-36 491.7782793806458
# CPU.S1|buy-dismiss|DC4,0.6-24 -2802.1003871355115
# CPU.S1|buy-dismiss|DC4,0.6-12 -6106.538766269292
# CPU.S1|buy-dismiss|DC4,0.65-96 16152.26831470466
# CPU.S1|buy-dismiss|DC4,0.65-84 14724.78915147339
# CPU.S1|buy-dismiss|DC4,0.65-72 12521.818232277852
# CPU.S1|buy-dismiss|DC4,0.65-60 9636.796538498575
# CPU.S1|buy-dismiss|DC4,0.65-48 6180.287542968418
# CPU.S1|buy-dismiss|DC4,0.65-36 2287.759802662367
# CPU.S1|buy-dismiss|DC4,0.65-24 -1865.608752730136
# CPU.S1|buy-dismiss|DC4,0.65-12 -6030.416996791734
# CPU.S1|buy-dismiss|DC4,0.7-96 22434.750492758867
# CPU.S1|buy-dismiss|DC4,0.7-84 20267.465240048266
# CPU.S1|buy-dismiss|DC4,0.7-72 17265.035019376148
# CPU.S1|buy-dismiss|DC4,0.7-60 13528.088579921541
# CPU.S1|buy-dismiss|DC4,0.7-48 9175.69427704291
# CPU.S1|buy-dismiss|DC4,0.7-36 4353.741325944086
# CPU.S1|buy-dismiss|DC4,0.7-24 -749.1171183247625
# CPU.S1|buy-dismiss|DC4,0.7-12 -5864.295227314175
# CPU.S1|buy-dismiss|DC4,0.75-96 29437.232670813068
# CPU.S1|buy-dismiss|DC4,0.75-84 26440.14132862314
# CPU.S1|buy-dismiss|DC4,0.75-72 22548.251806474444
# CPU.S1|buy-dismiss|DC4,0.75-60 17869.38062134451
# CPU.S1|buy-dismiss|DC4,0.75-48 12531.101011117406
# CPU.S1|buy-dismiss|DC4,0.75-36 6689.722849225809
# CPU.S1|buy-dismiss|DC4,0.75-24 547.374516080612
# CPU.S1|buy-dismiss|DC4,0.75-12 -5608.173457836616
# CPU.S1|buy-dismiss|DC4,0.8-96 37159.714848867276
# CPU.S1|buy-dismiss|DC4,0.8-84 33242.81741719802
# CPU.S1|buy-dismiss|DC4,0.8-72 28371.468593572743
# CPU.S1|buy-dismiss|DC4,0.8-60 22660.67266276748
# CPU.S1|buy-dismiss|DC4,0.8-48 16246.5077451919
# CPU.S1|buy-dismiss|DC4,0.8-36 9295.704372507527
# CPU.S1|buy-dismiss|DC4,0.8-24 2023.8661504859847
# CPU.S1|buy-dismiss|DC4,0.8-12 -5262.051688359057
# CPU.S1|buy-dismiss|DC4,0.85-96 45602.19702692148
# CPU.S1|buy-dismiss|DC4,0.85-84 40675.493505772894
# CPU.S1|buy-dismiss|DC4,0.85-72 34734.685380671035
# CPU.S1|buy-dismiss|DC4,0.85-60 27901.964704190443
# CPU.S1|buy-dismiss|DC4,0.85-48 20321.914479266397
# CPU.S1|buy-dismiss|DC4,0.85-36 12171.685895789251
# CPU.S1|buy-dismiss|DC4,0.85-24 3680.3577848913583
# CPU.S1|buy-dismiss|DC4,0.85-12 -4825.929918881497
# CPU.S1|buy-dismiss|DC4,0.9-96 54764.679204975684
# CPU.S1|buy-dismiss|DC4,0.9-84 48738.169594347775
# CPU.S1|buy-dismiss|DC4,0.9-72 41637.90216776934
# CPU.S1|buy-dismiss|DC4,0.9-60 33593.25674561341
# CPU.S1|buy-dismiss|DC4,0.9-48 24757.321213340892
# CPU.S1|buy-dismiss|DC4,0.9-36 15317.667419070973
# CPU.S1|buy-dismiss|DC4,0.9-24 5516.849419296735
# CPU.S1|buy-dismiss|DC4,0.9-12 -4299.808149403938
# CPU.S1|buy-dismiss|DC4,0.95-96 64647.16138302989
# CPU.S1|buy-dismiss|DC4,0.95-84 57430.84568292265
# CPU.S1|buy-dismiss|DC4,0.95-72 49081.118954867634
# CPU.S1|buy-dismiss|DC4,0.95-60 39734.54878703638
# CPU.S1|buy-dismiss|DC4,0.95-48 29552.727947415384
# CPU.S1|buy-dismiss|DC4,0.95-36 18733.648942352695
# CPU.S1|buy-dismiss|DC4,0.95-24 7533.34105370211
# CPU.S1|buy-dismiss|DC4,0.95-12 -3683.68637992638
# CPU.S1|buy-dismiss|DC4,1.0-96 75249.64356108409
# CPU.S1|buy-dismiss|DC4,1.0-84 66753.52177149752
# CPU.S1|buy-dismiss|DC4,1.0-72 57064.33574196593
# CPU.S1|buy-dismiss|DC4,1.0-60 46325.84082845934
# CPU.S1|buy-dismiss|DC4,1.0-48 34708.13468148987
# CPU.S1|buy-dismiss|DC4,1.0-36 22419.630465634415
# CPU.S1|buy-dismiss|DC4,1.0-24 9729.832688107483
# CPU.S1|buy-dismiss|DC4,1.0-12 -2977.5646104488205
# CPU.S2|buy-dismiss|DC1,0.05-96 -2506.1510040253647
# CPU.S2|buy-dismiss|DC1,0.05-84 -2143.957516385202
# CPU.S2|buy-dismiss|DC1,0.05-72 -1845.5598249087666
# CPU.S2|buy-dismiss|DC1,0.05-60 -1603.2710112559932
# CPU.S2|buy-dismiss|DC1,0.05-48 -1407.995576059222
# CPU.S2|buy-dismiss|DC1,0.05-36 -1248.5892042681596
# CPU.S2|buy-dismiss|DC1,0.05-24 -1110.6408909831416
# CPU.S2|buy-dismiss|DC1,0.05-12 -973.6336631976105
# CPU.S2|buy-dismiss|DC1,0.1-96 -4652.3020080507295
# CPU.S2|buy-dismiss|DC1,0.1-84 -3972.9150327704037
# CPU.S2|buy-dismiss|DC1,0.1-72 -3421.119649817533
# CPU.S2|buy-dismiss|DC1,0.1-60 -2981.5420225119865
# CPU.S2|buy-dismiss|DC1,0.1-48 -2635.991152118444
# CPU.S2|buy-dismiss|DC1,0.1-36 -2362.1784085363192
# CPU.S2|buy-dismiss|DC1,0.1-24 -2131.2817819662832
# CPU.S2|buy-dismiss|DC1,0.1-12 -1902.267326395221
# CPU.S2|buy-dismiss|DC1,0.15-96 -6438.453012076094
# CPU.S2|buy-dismiss|DC1,0.15-84 -5486.872549155605
# CPU.S2|buy-dismiss|DC1,0.15-72 -4726.679474726299
# CPU.S2|buy-dismiss|DC1,0.15-60 -4134.8130337679795
# CPU.S2|buy-dismiss|DC1,0.15-48 -3683.986728177666
# CPU.S2|buy-dismiss|DC1,0.15-36 -3340.7676128044795
# CPU.S2|buy-dismiss|DC1,0.15-24 -3061.922672949425
# CPU.S2|buy-dismiss|DC1,0.15-12 -2785.900989592832
# CPU.S2|buy-dismiss|DC1,0.2-96 -7864.604016101459
# CPU.S2|buy-dismiss|DC1,0.2-84 -6685.8300655408075
# CPU.S2|buy-dismiss|DC1,0.2-72 -5762.239299635066
# CPU.S2|buy-dismiss|DC1,0.2-60 -5063.084045023973
# CPU.S2|buy-dismiss|DC1,0.2-48 -4551.982304236888
# CPU.S2|buy-dismiss|DC1,0.2-36 -4184.3568170726385
# CPU.S2|buy-dismiss|DC1,0.2-24 -3902.563563932566
# CPU.S2|buy-dismiss|DC1,0.2-12 -3624.534652790442
# CPU.S2|buy-dismiss|DC1,0.25-96 -8930.755020126824
# CPU.S2|buy-dismiss|DC1,0.25-84 -7569.78758192601
# CPU.S2|buy-dismiss|DC1,0.25-72 -6527.799124543835
# CPU.S2|buy-dismiss|DC1,0.25-60 -5766.355056279967
# CPU.S2|buy-dismiss|DC1,0.25-48 -5239.97788029611
# CPU.S2|buy-dismiss|DC1,0.25-36 -4892.9460213408
# CPU.S2|buy-dismiss|DC1,0.25-24 -4653.204454915709
# CPU.S2|buy-dismiss|DC1,0.25-12 -4418.168315988053
# CPU.S2|buy-dismiss|DC1,0.3-96 -9636.906024152187
# CPU.S2|buy-dismiss|DC1,0.3-84 -8138.74509831121
# CPU.S2|buy-dismiss|DC1,0.3-72 -7023.3589494525995
# CPU.S2|buy-dismiss|DC1,0.3-60 -6244.626067535961
# CPU.S2|buy-dismiss|DC1,0.3-48 -5747.973456355332
# CPU.S2|buy-dismiss|DC1,0.3-36 -5466.535225608959
# CPU.S2|buy-dismiss|DC1,0.3-24 -5313.84534589885
# CPU.S2|buy-dismiss|DC1,0.3-12 -5166.801979185664
# CPU.S2|buy-dismiss|DC1,0.35-96 -9983.05702817755
# CPU.S2|buy-dismiss|DC1,0.35-84 -8392.702614696413
# CPU.S2|buy-dismiss|DC1,0.35-72 -7248.918774361365
# CPU.S2|buy-dismiss|DC1,0.35-60 -6497.897078791952
# CPU.S2|buy-dismiss|DC1,0.35-48 -6075.969032414552
# CPU.S2|buy-dismiss|DC1,0.35-36 -5905.124429877118
# CPU.S2|buy-dismiss|DC1,0.35-24 -5884.486236881989
# CPU.S2|buy-dismiss|DC1,0.35-12 -5870.435642383272
# CPU.S2|buy-dismiss|DC1,0.4-96 -9969.208032202916
# CPU.S2|buy-dismiss|DC1,0.4-84 -8331.660131081613
# CPU.S2|buy-dismiss|DC1,0.4-72 -7204.478599270133
# CPU.S2|buy-dismiss|DC1,0.4-60 -6526.168090047946
# CPU.S2|buy-dismiss|DC1,0.4-48 -6223.964608473775
# CPU.S2|buy-dismiss|DC1,0.4-36 -6208.71363414528
# CPU.S2|buy-dismiss|DC1,0.4-24 -6365.127127865132
# CPU.S2|buy-dismiss|DC1,0.4-12 -6529.069305580884
# CPU.S2|buy-dismiss|DC1,0.45-96 -9595.359036228281
# CPU.S2|buy-dismiss|DC1,0.45-84 -7955.6176474668155
# CPU.S2|buy-dismiss|DC1,0.45-72 -6890.038424178899
# CPU.S2|buy-dismiss|DC1,0.45-60 -6329.439101303938
# CPU.S2|buy-dismiss|DC1,0.45-48 -6191.960184532996
# CPU.S2|buy-dismiss|DC1,0.45-36 -6377.302838413439
# CPU.S2|buy-dismiss|DC1,0.45-24 -6755.768018848273
# CPU.S2|buy-dismiss|DC1,0.45-12 -7142.702968778495
# CPU.S2|buy-dismiss|DC1,0.5-96 -8861.510040253645
# CPU.S2|buy-dismiss|DC1,0.5-84 -7264.575163852019
# CPU.S2|buy-dismiss|DC1,0.5-72 -6305.598249087665
# CPU.S2|buy-dismiss|DC1,0.5-60 -5907.710112559931
# CPU.S2|buy-dismiss|DC1,0.5-48 -5979.95576059222
# CPU.S2|buy-dismiss|DC1,0.5-36 -6410.892042681599
# CPU.S2|buy-dismiss|DC1,0.5-24 -7056.408909831416
# CPU.S2|buy-dismiss|DC1,0.5-12 -7711.336631976107
# CPU.S2|buy-dismiss|DC1,0.55-96 -7767.661044279007
# CPU.S2|buy-dismiss|DC1,0.55-84 -6258.532680237217
# CPU.S2|buy-dismiss|DC1,0.55-72 -5451.15807399643
# CPU.S2|buy-dismiss|DC1,0.55-60 -5260.981123815924
# CPU.S2|buy-dismiss|DC1,0.55-48 -5587.951336651441
# CPU.S2|buy-dismiss|DC1,0.55-36 -6309.481246949759
# CPU.S2|buy-dismiss|DC1,0.55-24 -7267.049800814558
# CPU.S2|buy-dismiss|DC1,0.55-12 -8234.970295173714
# CPU.S2|buy-dismiss|DC1,0.6-96 -6313.812048304376
# CPU.S2|buy-dismiss|DC1,0.6-84 -4937.490196622424
# CPU.S2|buy-dismiss|DC1,0.6-72 -4326.717898905199
# CPU.S2|buy-dismiss|DC1,0.6-60 -4389.252135071921
# CPU.S2|buy-dismiss|DC1,0.6-48 -5015.946912710665
# CPU.S2|buy-dismiss|DC1,0.6-36 -6073.07045121792
# CPU.S2|buy-dismiss|DC1,0.6-24 -7387.690691797699
# CPU.S2|buy-dismiss|DC1,0.6-12 -8713.603958371328
# CPU.S2|buy-dismiss|DC1,0.65-96 -4499.963052329739
# CPU.S2|buy-dismiss|DC1,0.65-84 -3301.4477130076243
# CPU.S2|buy-dismiss|DC1,0.65-72 -2932.2777238139624
# CPU.S2|buy-dismiss|DC1,0.65-60 -3292.5231463279106
# CPU.S2|buy-dismiss|DC1,0.65-48 -4263.942488769885
# CPU.S2|buy-dismiss|DC1,0.65-36 -5701.659655486078
# CPU.S2|buy-dismiss|DC1,0.65-24 -7418.331582780839
# CPU.S2|buy-dismiss|DC1,0.65-12 -9147.237621568938
# CPU.S2|buy-dismiss|DC1,0.7-96 -2326.1140563551016
# CPU.S2|buy-dismiss|DC1,0.7-84 -1350.4052293928253
# CPU.S2|buy-dismiss|DC1,0.7-72 -1267.8375487227295
# CPU.S2|buy-dismiss|DC1,0.7-60 -1970.794157583902
# CPU.S2|buy-dismiss|DC1,0.7-48 -3331.9380648291053
# CPU.S2|buy-dismiss|DC1,0.7-36 -5195.248859754236
# CPU.S2|buy-dismiss|DC1,0.7-24 -7358.972473763977
# CPU.S2|buy-dismiss|DC1,0.7-12 -9535.871284766545
# CPU.S2|buy-dismiss|DC1,0.75-96 207.73493961953318
# CPU.S2|buy-dismiss|DC1,0.75-84 915.6372542219709
# CPU.S2|buy-dismiss|DC1,0.75-72 666.6026263685026
# CPU.S2|buy-dismiss|DC1,0.75-60 -424.0651688398975
# CPU.S2|buy-dismiss|DC1,0.75-48 -2219.933640888329
# CPU.S2|buy-dismiss|DC1,0.75-36 -4553.8380640223995
# CPU.S2|buy-dismiss|DC1,0.75-24 -7209.613364747125
# CPU.S2|buy-dismiss|DC1,0.75-12 -9879.504947964158
# CPU.S2|buy-dismiss|DC1,0.8-96 3101.5839355941707
# CPU.S2|buy-dismiss|DC1,0.8-84 3496.679737836773
# CPU.S2|buy-dismiss|DC1,0.8-72 2871.0428014597373
# CPU.S2|buy-dismiss|DC1,0.8-60 1347.6638199041095
# CPU.S2|buy-dismiss|DC1,0.8-48 -927.9292169475511
# CPU.S2|buy-dismiss|DC1,0.8-36 -3777.4272682905575
# CPU.S2|buy-dismiss|DC1,0.8-24 -6970.254255730264
# CPU.S2|buy-dismiss|DC1,0.8-12 -10178.138611161768
# CPU.S2|buy-dismiss|DC1,0.85-96 6355.432931568803
# CPU.S2|buy-dismiss|DC1,0.85-84 6392.722221451568
# CPU.S2|buy-dismiss|DC1,0.85-72 5345.482976550971
# CPU.S2|buy-dismiss|DC1,0.85-60 3344.3928086481155
# CPU.S2|buy-dismiss|DC1,0.85-48 544.075206993226
# CPU.S2|buy-dismiss|DC1,0.85-36 -2866.0164725587174
# CPU.S2|buy-dismiss|DC1,0.85-24 -6640.895146713408
# CPU.S2|buy-dismiss|DC1,0.85-12 -10431.77227435938
# CPU.S2|buy-dismiss|DC1,0.9-96 9969.28192754344
# CPU.S2|buy-dismiss|DC1,0.9-84 9603.76470506637
# CPU.S2|buy-dismiss|DC1,0.9-72 8089.923151642202
# CPU.S2|buy-dismiss|DC1,0.9-60 5566.121797392126
# CPU.S2|buy-dismiss|DC1,0.9-48 2196.0796309340094
# CPU.S2|buy-dismiss|DC1,0.9-36 -1819.6056768268757
# CPU.S2|buy-dismiss|DC1,0.9-24 -6221.5360376965455
# CPU.S2|buy-dismiss|DC1,0.9-12 -10640.40593755699
# CPU.S2|buy-dismiss|DC1,0.95-96 13943.130923518074
# CPU.S2|buy-dismiss|DC1,0.95-84 13129.807188681167
# CPU.S2|buy-dismiss|DC1,0.95-72 11104.363326733437
# CPU.S2|buy-dismiss|DC1,0.95-60 8012.85078613613
# CPU.S2|buy-dismiss|DC1,0.95-48 4028.084054874783
# CPU.S2|buy-dismiss|DC1,0.95-36 -638.1948810950373
# CPU.S2|buy-dismiss|DC1,0.95-24 -5712.176928679688
# CPU.S2|buy-dismiss|DC1,0.95-12 -10804.039600754597
# CPU.S2|buy-dismiss|DC1,1.0-96 18276.97991949271
# CPU.S2|buy-dismiss|DC1,1.0-84 16970.84967229596
# CPU.S2|buy-dismiss|DC1,1.0-72 14388.80350182467
# CPU.S2|buy-dismiss|DC1,1.0-60 10684.579774880136
# CPU.S2|buy-dismiss|DC1,1.0-48 6040.088478815563
# CPU.S2|buy-dismiss|DC1,1.0-36 678.2159146368028
# CPU.S2|buy-dismiss|DC1,1.0-24 -5112.817819662831
# CPU.S2|buy-dismiss|DC1,1.0-12 -10922.673263952214
# CPU.S2|buy-dismiss|DC2,0.05-96 -2636.951004025365
# CPU.S2|buy-dismiss|DC2,0.05-84 -2258.4075163852017
# CPU.S2|buy-dismiss|DC2,0.05-72 -1943.6598249087665
# CPU.S2|buy-dismiss|DC2,0.05-60 -1685.0210112559932
# CPU.S2|buy-dismiss|DC2,0.05-48 -1473.395576059222
# CPU.S2|buy-dismiss|DC2,0.05-36 -1297.6392042681603
# CPU.S2|buy-dismiss|DC2,0.05-24 -1143.3408909831414
# CPU.S2|buy-dismiss|DC2,0.05-12 -989.9836631976107
# CPU.S2|buy-dismiss|DC2,0.1-96 -4733.90200805073
# CPU.S2|buy-dismiss|DC2,0.1-84 -4044.3150327704043
# CPU.S2|buy-dismiss|DC2,0.1-72 -3482.319649817533
# CPU.S2|buy-dismiss|DC2,0.1-60 -3032.5420225119865
# CPU.S2|buy-dismiss|DC2,0.1-48 -2676.791152118444
# CPU.S2|buy-dismiss|DC2,0.1-36 -2392.7784085363205
# CPU.S2|buy-dismiss|DC2,0.1-24 -2151.681781966283
# CPU.S2|buy-dismiss|DC2,0.1-12 -1912.4673263952213
# CPU.S2|buy-dismiss|DC2,0.15-96 -6290.853012076093
# CPU.S2|buy-dismiss|DC2,0.15-84 -5357.722549155605
# CPU.S2|buy-dismiss|DC2,0.15-72 -4615.979474726299
# CPU.S2|buy-dismiss|DC2,0.15-60 -4042.5630337679786
# CPU.S2|buy-dismiss|DC2,0.15-48 -3610.186728177665
# CPU.S2|buy-dismiss|DC2,0.15-36 -3285.417612804479
# CPU.S2|buy-dismiss|DC2,0.15-24 -3025.0226729494243
# CPU.S2|buy-dismiss|DC2,0.15-12 -2767.450989592831
# CPU.S2|buy-dismiss|DC2,0.2-96 -7307.80401610146
# CPU.S2|buy-dismiss|DC2,0.2-84 -6198.630065540808
# CPU.S2|buy-dismiss|DC2,0.2-72 -5344.639299635067
# CPU.S2|buy-dismiss|DC2,0.2-60 -4715.084045023973
# CPU.S2|buy-dismiss|DC2,0.2-48 -4273.5823042368875
# CPU.S2|buy-dismiss|DC2,0.2-36 -3975.5568170726397
# CPU.S2|buy-dismiss|DC2,0.2-24 -3763.363563932566
# CPU.S2|buy-dismiss|DC2,0.2-12 -3554.9346527904427
# CPU.S2|buy-dismiss|DC2,0.25-96 -7784.755020126823
# CPU.S2|buy-dismiss|DC2,0.25-84 -6567.03758192601
# CPU.S2|buy-dismiss|DC2,0.25-72 -5668.299124543833
# CPU.S2|buy-dismiss|DC2,0.25-60 -5050.105056279966
# CPU.S2|buy-dismiss|DC2,0.25-48 -4666.977880296109
# CPU.S2|buy-dismiss|DC2,0.25-36 -4463.196021340799
# CPU.S2|buy-dismiss|DC2,0.25-24 -4366.704454915708
# CPU.S2|buy-dismiss|DC2,0.25-12 -4274.918315988053
# CPU.S2|buy-dismiss|DC2,0.3-96 -7721.706024152185
# CPU.S2|buy-dismiss|DC2,0.3-84 -6462.94509831121
# CPU.S2|buy-dismiss|DC2,0.3-72 -5586.958949452598
# CPU.S2|buy-dismiss|DC2,0.3-60 -5047.626067535957
# CPU.S2|buy-dismiss|DC2,0.3-48 -4790.373456355331
# CPU.S2|buy-dismiss|DC2,0.3-36 -4748.335225608958
# CPU.S2|buy-dismiss|DC2,0.3-24 -4835.045345898849
# CPU.S2|buy-dismiss|DC2,0.3-12 -4927.401979185662
# CPU.S2|buy-dismiss|DC2,0.35-96 -7118.657028177552
# CPU.S2|buy-dismiss|DC2,0.35-84 -5886.352614696412
# CPU.S2|buy-dismiss|DC2,0.35-72 -5100.618774361365
# CPU.S2|buy-dismiss|DC2,0.35-60 -4707.647078791952
# CPU.S2|buy-dismiss|DC2,0.35-48 -4643.769032414553
# CPU.S2|buy-dismiss|DC2,0.35-36 -4830.974429877118
# CPU.S2|buy-dismiss|DC2,0.35-24 -5168.38623688199
# CPU.S2|buy-dismiss|DC2,0.35-12 -5512.385642383274
# CPU.S2|buy-dismiss|DC2,0.4-96 -5975.6080322029175
# CPU.S2|buy-dismiss|DC2,0.4-84 -4837.260131081615
# CPU.S2|buy-dismiss|DC2,0.4-72 -4209.278599270134
# CPU.S2|buy-dismiss|DC2,0.4-60 -4030.168090047946
# CPU.S2|buy-dismiss|DC2,0.4-48 -4227.164608473776
# CPU.S2|buy-dismiss|DC2,0.4-36 -4711.113634145279
# CPU.S2|buy-dismiss|DC2,0.4-24 -5366.727127865132
# CPU.S2|buy-dismiss|DC2,0.4-12 -6029.869305580885
# CPU.S2|buy-dismiss|DC2,0.45-96 -4292.55903622828
# CPU.S2|buy-dismiss|DC2,0.45-84 -3315.6676474668157
# CPU.S2|buy-dismiss|DC2,0.45-72 -2912.9384241788975
# CPU.S2|buy-dismiss|DC2,0.45-60 -3015.1891013039385
# CPU.S2|buy-dismiss|DC2,0.45-48 -3540.560184532997
# CPU.S2|buy-dismiss|DC2,0.45-36 -4388.752838413438
# CPU.S2|buy-dismiss|DC2,0.45-24 -5430.068018848274
# CPU.S2|buy-dismiss|DC2,0.45-12 -6479.852968778496
# CPU.S2|buy-dismiss|DC2,0.5-96 -2069.5100402536445
# CPU.S2|buy-dismiss|DC2,0.5-84 -1321.5751638520185
# CPU.S2|buy-dismiss|DC2,0.5-72 -1211.5982490876645
# CPU.S2|buy-dismiss|DC2,0.5-60 -1662.7101125599313
# CPU.S2|buy-dismiss|DC2,0.5-48 -2583.955760592218
# CPU.S2|buy-dismiss|DC2,0.5-36 -3863.892042681598
# CPU.S2|buy-dismiss|DC2,0.5-24 -5358.408909831416
# CPU.S2|buy-dismiss|DC2,0.5-12 -6862.336631976107
# CPU.S2|buy-dismiss|DC2,0.55-96 693.538955720991
# CPU.S2|buy-dismiss|DC2,0.55-84 1145.0173197627796
# CPU.S2|buy-dismiss|DC2,0.55-72 894.7419260035676
# CPU.S2|buy-dismiss|DC2,0.55-60 27.268876184074486
# CPU.S2|buy-dismiss|DC2,0.55-48 -1357.3513366514421
# CPU.S2|buy-dismiss|DC2,0.55-36 -3136.5312469497594
# CPU.S2|buy-dismiss|DC2,0.55-24 -5151.749800814557
# CPU.S2|buy-dismiss|DC2,0.55-12 -7177.320295173718
# CPU.S2|buy-dismiss|DC2,0.6-96 3996.587951695628
# CPU.S2|buy-dismiss|DC2,0.6-84 4084.109803377579
# CPU.S2|buy-dismiss|DC2,0.6-72 3406.082101094804
# CPU.S2|buy-dismiss|DC2,0.6-60 2054.7478649280847
# CPU.S2|buy-dismiss|DC2,0.6-48 139.2530872893385
# CPU.S2|buy-dismiss|DC2,0.6-36 -2206.670451217915
# CPU.S2|buy-dismiss|DC2,0.6-24 -4810.090691797697
# CPU.S2|buy-dismiss|DC2,0.6-12 -7424.803958371326
# CPU.S2|buy-dismiss|DC2,0.65-96 7839.636947670264
# CPU.S2|buy-dismiss|DC2,0.65-84 7495.702286992378
# CPU.S2|buy-dismiss|DC2,0.65-72 6322.4222761860365
# CPU.S2|buy-dismiss|DC2,0.65-60 4419.726853672091
# CPU.S2|buy-dismiss|DC2,0.65-48 1905.857511230115
# CPU.S2|buy-dismiss|DC2,0.65-36 -1074.309655486078
# CPU.S2|buy-dismiss|DC2,0.65-24 -4333.431582780841
# CPU.S2|buy-dismiss|DC2,0.65-12 -7604.78762156894
# CPU.S2|buy-dismiss|DC2,0.7-96 12222.685943644894
# CPU.S2|buy-dismiss|DC2,0.7-84 11379.794770607174
# CPU.S2|buy-dismiss|DC2,0.7-72 9643.762451277269
# CPU.S2|buy-dismiss|DC2,0.7-60 7122.205842416094
# CPU.S2|buy-dismiss|DC2,0.7-48 3942.461935170892
# CPU.S2|buy-dismiss|DC2,0.7-36 260.5511402457614
# CPU.S2|buy-dismiss|DC2,0.7-24 -3721.772473763981
# CPU.S2|buy-dismiss|DC2,0.7-12 -7717.271284766549
# CPU.S2|buy-dismiss|DC2,0.75-96 17145.73493961953
# CPU.S2|buy-dismiss|DC2,0.75-84 15736.387254221972
# CPU.S2|buy-dismiss|DC2,0.75-72 13370.102626368502
# CPU.S2|buy-dismiss|DC2,0.75-60 10162.1848311601
# CPU.S2|buy-dismiss|DC2,0.75-48 6249.066359111669
# CPU.S2|buy-dismiss|DC2,0.75-36 1797.9119359776005
# CPU.S2|buy-dismiss|DC2,0.75-24 -2975.113364747125
# CPU.S2|buy-dismiss|DC2,0.75-12 -7762.254947964158
# CPU.S2|buy-dismiss|DC2,0.8-96 22608.78393559417
# CPU.S2|buy-dismiss|DC2,0.8-84 20565.47973783677
# CPU.S2|buy-dismiss|DC2,0.8-72 17501.442801459736
# CPU.S2|buy-dismiss|DC2,0.8-60 13539.66381990411
# CPU.S2|buy-dismiss|DC2,0.8-48 8825.67078305245
# CPU.S2|buy-dismiss|DC2,0.8-36 3537.7727317094414
# CPU.S2|buy-dismiss|DC2,0.8-24 -2093.454255730265
# CPU.S2|buy-dismiss|DC2,0.8-12 -7739.73861116177
# CPU.S2|buy-dismiss|DC2,0.85-96 28611.83293156881
# CPU.S2|buy-dismiss|DC2,0.85-84 25867.072221451566
# CPU.S2|buy-dismiss|DC2,0.85-72 22037.782976550974
# CPU.S2|buy-dismiss|DC2,0.85-60 17254.642808648117
# CPU.S2|buy-dismiss|DC2,0.85-48 11672.275206993228
# CPU.S2|buy-dismiss|DC2,0.85-36 5480.133527441283
# CPU.S2|buy-dismiss|DC2,0.85-24 -1076.7951467134044
# CPU.S2|buy-dismiss|DC2,0.85-12 -7649.722274359378
# CPU.S2|buy-dismiss|DC2,0.9-96 35154.88192754345
# CPU.S2|buy-dismiss|DC2,0.9-84 31641.164705066374
# CPU.S2|buy-dismiss|DC2,0.9-72 26979.12315164221
# CPU.S2|buy-dismiss|DC2,0.9-60 21307.121797392127
# CPU.S2|buy-dismiss|DC2,0.9-48 14788.879630934007
# CPU.S2|buy-dismiss|DC2,0.9-36 7624.994323173124
# CPU.S2|buy-dismiss|DC2,0.9-24 74.86396230345144
# CPU.S2|buy-dismiss|DC2,0.9-12 -7492.205937556992
# CPU.S2|buy-dismiss|DC2,0.95-96 42237.93092351808
# CPU.S2|buy-dismiss|DC2,0.95-84 37887.757188681164
# CPU.S2|buy-dismiss|DC2,0.95-72 32325.463326733436
# CPU.S2|buy-dismiss|DC2,0.95-60 25697.100786136132
# CPU.S2|buy-dismiss|DC2,0.95-48 18175.48405487478
# CPU.S2|buy-dismiss|DC2,0.95-36 9972.355118904963
# CPU.S2|buy-dismiss|DC2,0.95-24 1361.523071320311
# CPU.S2|buy-dismiss|DC2,0.95-12 -7267.1896007546
# CPU.S2|buy-dismiss|DC2,1.0-96 49860.9799194927
# CPU.S2|buy-dismiss|DC2,1.0-84 44606.84967229596
# CPU.S2|buy-dismiss|DC2,1.0-72 38076.803501824674
# CPU.S2|buy-dismiss|DC2,1.0-60 30424.57977488013
# CPU.S2|buy-dismiss|DC2,1.0-48 21832.088478815564
# CPU.S2|buy-dismiss|DC2,1.0-36 12522.215914636803
# CPU.S2|buy-dismiss|DC2,1.0-24 2783.1821803371686
# CPU.S2|buy-dismiss|DC2,1.0-12 -6974.673263952213
# CPU.S2|buy-dismiss|DC3,0.05-96 -3119.351004025364
# CPU.S2|buy-dismiss|DC3,0.05-84 -2680.5075163852016
# CPU.S2|buy-dismiss|DC3,0.05-72 -2305.4598249087667
# CPU.S2|buy-dismiss|DC3,0.05-60 -1986.521011255993
# CPU.S2|buy-dismiss|DC3,0.05-48 -1714.595576059222
# CPU.S2|buy-dismiss|DC3,0.05-36 -1478.53920426816
# CPU.S2|buy-dismiss|DC3,0.05-24 -1263.9408909831416
# CPU.S2|buy-dismiss|DC3,0.05-12 -1050.2836631976106
# CPU.S2|buy-dismiss|DC3,0.1-96 -5338.702008050728
# CPU.S2|buy-dismiss|DC3,0.1-84 -4573.515032770403
# ...
# GPU.S3|buy-dismiss|DC2,1.0-48 625840.8847881556
# GPU.S3|buy-dismiss|DC2,1.0-36 430862.159146368
# GPU.S3|buy-dismiss|DC2,1.0-24 231591.82180337168
# GPU.S3|buy-dismiss|DC2,1.0-12 32133.267360477897
# GPU.S3|buy-dismiss|DC3,0.05-96 -29261.51004025365
# GPU.S3|buy-dismiss|DC3,0.05-84 -25114.57516385202
# GPU.S3|buy-dismiss|DC3,0.05-72 -21605.59824908767
# GPU.S3|buy-dismiss|DC3,0.05-60 -18657.710112559933
# GPU.S3|buy-dismiss|DC3,0.05-48 -16179.95576059222
# GPU.S3|buy-dismiss|DC3,0.05-36 -14060.8920426816
# GPU.S3|buy-dismiss|DC3,0.05-24 -12156.408909831418
# GPU.S3|buy-dismiss|DC3,0.05-12 -10261.336631976106
# GPU.S3|buy-dismiss|DC3,0.1-96 -48155.0200805073
# GPU.S3|buy-dismiss|DC3,0.1-84 -41157.150327704054
# GPU.S3|buy-dismiss|DC3,0.1-72 -35435.19649817534
# GPU.S3|buy-dismiss|DC3,0.1-60 -30835.42022511987
# GPU.S3|buy-dismiss|DC3,0.1-48 -27175.91152118444
# GPU.S3|buy-dismiss|DC3,0.1-36 -24233.7840853632
# GPU.S3|buy-dismiss|DC3,0.1-24 -21720.817819662836
# GPU.S3|buy-dismiss|DC3,0.1-12 -19226.673263952212
# GPU.S3|buy-dismiss|DC3,0.15-96 -56680.53012076093
# GPU.S3|buy-dismiss|DC3,0.15-84 -48127.725491556055
# GPU.S3|buy-dismiss|DC3,0.15-72 -41488.794747263
# GPU.S3|buy-dismiss|DC3,0.15-60 -36533.130337679795
# GPU.S3|buy-dismiss|DC3,0.15-48 -32987.86728177666
# GPU.S3|buy-dismiss|DC3,0.15-36 -30518.6761280448
# GPU.S3|buy-dismiss|DC3,0.15-24 -28693.22672949425
# GPU.S3|buy-dismiss|DC3,0.15-12 -26896.009895928317
# GPU.S3|buy-dismiss|DC3,0.2-96 -54838.04016101458
# GPU.S3|buy-dismiss|DC3,0.2-84 -46026.30065540807
# GPU.S3|buy-dismiss|DC3,0.2-72 -39766.39299635067
# GPU.S3|buy-dismiss|DC3,0.2-60 -35750.84045023973
# GPU.S3|buy-dismiss|DC3,0.2-48 -33615.82304236888
# GPU.S3|buy-dismiss|DC3,0.2-36 -32915.568170726394
# GPU.S3|buy-dismiss|DC3,0.2-24 -33073.635639325665
# GPU.S3|buy-dismiss|DC3,0.2-12 -33269.346527904425
# GPU.S3|buy-dismiss|DC3,0.25-96 -42627.55020126823
# GPU.S3|buy-dismiss|DC3,0.25-84 -34852.875819260094
# GPU.S3|buy-dismiss|DC3,0.25-72 -30267.991245438327
# GPU.S3|buy-dismiss|DC3,0.25-60 -28488.550562799664
# GPU.S3|buy-dismiss|DC3,0.25-48 -29059.778802961097
# GPU.S3|buy-dismiss|DC3,0.25-36 -31424.460213407994
# GPU.S3|buy-dismiss|DC3,0.25-24 -34862.04454915708
# GPU.S3|buy-dismiss|DC3,0.25-12 -38346.68315988053
# GPU.S3|buy-dismiss|DC3,0.3-96 -20049.060241521867
# GPU.S3|buy-dismiss|DC3,0.3-84 -14607.450983112121
# GPU.S3|buy-dismiss|DC3,0.3-72 -12993.589494525993
# GPU.S3|buy-dismiss|DC3,0.3-60 -14746.26067535959
# GPU.S3|buy-dismiss|DC3,0.3-48 -19319.734563553317
# GPU.S3|buy-dismiss|DC3,0.3-36 -26045.352256089598
# GPU.S3|buy-dismiss|DC3,0.3-24 -34058.4534589885
# GPU.S3|buy-dismiss|DC3,0.3-12 -42128.019791856634
# GPU.S3|buy-dismiss|DC3,0.35-96 12897.429718224448
# GPU.S3|buy-dismiss|DC3,0.35-84 14709.973853035846
# GPU.S3|buy-dismiss|DC3,0.35-72 12056.812256386314
# GPU.S3|buy-dismiss|DC3,0.35-60 5476.0292120804515
# GPU.S3|buy-dismiss|DC3,0.35-48 -4395.690324145551
# GPU.S3|buy-dismiss|DC3,0.35-36 -16778.244298771202
# GPU.S3|buy-dismiss|DC3,0.35-24 -30662.86236881992
# GPU.S3|buy-dismiss|DC3,0.35-12 -44613.356423832745
# GPU.S3|buy-dismiss|DC3,0.4-96 56211.91967797084
# GPU.S3|buy-dismiss|DC3,0.4-84 53099.39868918385
# GPU.S3|buy-dismiss|DC3,0.4-72 44883.21400729868
# GPU.S3|buy-dismiss|DC3,0.4-60 32178.319099520544
# GPU.S3|buy-dismiss|DC3,0.4-48 15712.35391526225
# GPU.S3|buy-dismiss|DC3,0.4-36 -3623.136341452789
# GPU.S3|buy-dismiss|DC3,0.4-24 -24675.271278651326
# GPU.S3|buy-dismiss|DC3,0.4-12 -45802.69305580885
# GPU.S3|buy-dismiss|DC3,0.45-96 109894.40963771718
# GPU.S3|buy-dismiss|DC3,0.45-84 100560.82352533184
# GPU.S3|buy-dismiss|DC3,0.45-72 85485.61575821103
# GPU.S3|buy-dismiss|DC3,0.45-60 65360.608986960615
# GPU.S3|buy-dismiss|DC3,0.45-48 41004.39815467002
# GPU.S3|buy-dismiss|DC3,0.45-36 13419.971615865607
# GPU.S3|buy-dismiss|DC3,0.45-24 -16095.680188482736
# GPU.S3|buy-dismiss|DC3,0.45-12 -45696.02968778494
# GPU.S3|buy-dismiss|DC3,0.5-96 173944.89959746355
# GPU.S3|buy-dismiss|DC3,0.5-84 157094.24836147978
# GPU.S3|buy-dismiss|DC3,0.5-72 133864.01750912334
# GPU.S3|buy-dismiss|DC3,0.5-60 105022.8988744007
# GPU.S3|buy-dismiss|DC3,0.5-48 71480.44239407779
# GPU.S3|buy-dismiss|DC3,0.5-36 34351.07957318402
# GPU.S3|buy-dismiss|DC3,0.5-24 -4924.089098314158
# GPU.S3|buy-dismiss|DC3,0.5-12 -44293.36631976106
# GPU.S3|buy-dismiss|DC3,0.55-96 248363.38955721003
# GPU.S3|buy-dismiss|DC3,0.55-84 222699.67319762785
# GPU.S3|buy-dismiss|DC3,0.55-72 190018.41926003573
# GPU.S3|buy-dismiss|DC3,0.55-60 151165.1887618408
# GPU.S3|buy-dismiss|DC3,0.55-48 107140.48663348565
# GPU.S3|buy-dismiss|DC3,0.55-36 59170.187530502444
# GPU.S3|buy-dismiss|DC3,0.55-24 8839.501991854464
# GPU.S3|buy-dismiss|DC3,0.55-12 -41594.70295173714
# GPU.S3|buy-dismiss|DC3,0.6-96 333149.8795169562
# GPU.S3|buy-dismiss|DC3,0.6-84 297377.09803377575
# GPU.S3|buy-dismiss|DC3,0.6-72 253948.82101094798
# GPU.S3|buy-dismiss|DC3,0.6-60 203787.4786492808
# GPU.S3|buy-dismiss|DC3,0.6-48 147984.53087289335
# GPU.S3|buy-dismiss|DC3,0.6-36 87877.2954878208
# GPU.S3|buy-dismiss|DC3,0.6-24 25195.093082023
# GPU.S3|buy-dismiss|DC3,0.6-12 -37600.039583713275
# GPU.S3|buy-dismiss|DC3,0.65-96 428304.36947670265
# GPU.S3|buy-dismiss|DC3,0.65-84 381126.52286992373
# GPU.S3|buy-dismiss|DC3,0.65-72 325655.22276186035
# GPU.S3|buy-dismiss|DC3,0.65-60 262889.7685367209
# GPU.S3|buy-dismiss|DC3,0.65-48 194012.57511230116
# GPU.S3|buy-dismiss|DC3,0.65-36 120472.40344513922
# GPU.S3|buy-dismiss|DC3,0.65-24 44142.684172191606
# GPU.S3|buy-dismiss|DC3,0.65-12 -32309.376215689375
# GPU.S3|buy-dismiss|DC3,0.7-96 533826.8594364489
# GPU.S3|buy-dismiss|DC3,0.7-84 473947.94770607154
# GPU.S3|buy-dismiss|DC3,0.7-72 405137.62451277254
# GPU.S3|buy-dismiss|DC3,0.7-60 328472.0584241609
# GPU.S3|buy-dismiss|DC3,0.7-48 245224.61935170885
# GPU.S3|buy-dismiss|DC3,0.7-36 156955.51140245755
# GPU.S3|buy-dismiss|DC3,0.7-24 65682.27526236016
# GPU.S3|buy-dismiss|DC3,0.7-12 -25722.712847665498
# GPU.S3|buy-dismiss|DC3,0.75-96 649717.3493961953
# GPU.S3|buy-dismiss|DC3,0.75-84 575841.3725422197
# GPU.S3|buy-dismiss|DC3,0.75-72 492396.0262636851
# GPU.S3|buy-dismiss|DC3,0.75-60 400534.34831160103
# GPU.S3|buy-dismiss|DC3,0.75-48 301620.6635911167
# GPU.S3|buy-dismiss|DC3,0.75-36 197326.61935977603
# GPU.S3|buy-dismiss|DC3,0.75-24 89813.86635252877
# GPU.S3|buy-dismiss|DC3,0.75-12 -17840.049479641588
# GPU.S3|buy-dismiss|DC3,0.8-96 775975.8393559416
# GPU.S3|buy-dismiss|DC3,0.8-84 686806.7973783677
# GPU.S3|buy-dismiss|DC3,0.8-72 587430.4280145974
# GPU.S3|buy-dismiss|DC3,0.8-60 479076.63819904113
# GPU.S3|buy-dismiss|DC3,0.8-48 363200.70783052454
# GPU.S3|buy-dismiss|DC3,0.8-36 241585.7273170944
# GPU.S3|buy-dismiss|DC3,0.8-24 116537.45744269734
# GPU.S3|buy-dismiss|DC3,0.8-12 -8661.386111617674
# GPU.S3|buy-dismiss|DC3,0.85-96 912602.329315688
# GPU.S3|buy-dismiss|DC3,0.85-84 806844.2222145157
# GPU.S3|buy-dismiss|DC3,0.85-72 690240.8297655097
# GPU.S3|buy-dismiss|DC3,0.85-60 564098.928086481
# GPU.S3|buy-dismiss|DC3,0.85-48 429964.7520699323
# GPU.S3|buy-dismiss|DC3,0.85-36 289732.83527441276
# GPU.S3|buy-dismiss|DC3,0.85-24 145853.04853286597
# GPU.S3|buy-dismiss|DC3,0.85-12 1813.277256406207
# GPU.S3|buy-dismiss|DC3,0.9-96 1059596.8192754346
# GPU.S3|buy-dismiss|DC3,0.9-84 935953.6470506636
# GPU.S3|buy-dismiss|DC3,0.9-72 800827.231516422
# GPU.S3|buy-dismiss|DC3,0.9-60 655601.2179739213
# GPU.S3|buy-dismiss|DC3,0.9-48 501912.79630934005
# GPU.S3|buy-dismiss|DC3,0.9-36 341767.94323173125
# GPU.S3|buy-dismiss|DC3,0.9-24 177760.63962303454
# GPU.S3|buy-dismiss|DC3,0.9-12 13583.940624430108
# GPU.S3|buy-dismiss|DC3,0.95-96 1216959.3092351807
# GPU.S3|buy-dismiss|DC3,0.95-84 1074135.0718868116
# GPU.S3|buy-dismiss|DC3,0.95-72 919189.6332673343
# GPU.S3|buy-dismiss|DC3,0.95-60 753583.5078613613
# GPU.S3|buy-dismiss|DC3,0.95-48 579044.8405487479
# GPU.S3|buy-dismiss|DC3,0.95-36 397691.0511890496
# GPU.S3|buy-dismiss|DC3,0.95-24 212260.23071320314
# GPU.S3|buy-dismiss|DC3,0.95-12 26650.60399245398
# GPU.S3|buy-dismiss|DC3,1.0-96 1384689.7991949269
# GPU.S3|buy-dismiss|DC3,1.0-84 1221388.4967229592
# GPU.S3|buy-dismiss|DC3,1.0-72 1045328.0350182466
# GPU.S3|buy-dismiss|DC3,1.0-60 858045.7977488013
# GPU.S3|buy-dismiss|DC3,1.0-48 661360.8847881556
# GPU.S3|buy-dismiss|DC3,1.0-36 457502.159146368
# GPU.S3|buy-dismiss|DC3,1.0-24 249351.82180337168
# GPU.S3|buy-dismiss|DC3,1.0-12 41013.26736047789
# GPU.S3|buy-dismiss|DC4,0.05-96 -31277.51004025365
# GPU.S3|buy-dismiss|DC4,0.05-84 -26878.57516385202
# GPU.S3|buy-dismiss|DC4,0.05-72 -23117.59824908767
# GPU.S3|buy-dismiss|DC4,0.05-60 -19917.710112559933
# GPU.S3|buy-dismiss|DC4,0.05-48 -17187.95576059222
# GPU.S3|buy-dismiss|DC4,0.05-36 -14816.8920426816
# GPU.S3|buy-dismiss|DC4,0.05-24 -12660.408909831418
# GPU.S3|buy-dismiss|DC4,0.05-12 -10513.336631976106
# GPU.S3|buy-dismiss|DC4,0.1-96 -52187.020080507304
# GPU.S3|buy-dismiss|DC4,0.1-84 -44685.150327704054
# GPU.S3|buy-dismiss|DC4,0.1-72 -38459.19649817534
# GPU.S3|buy-dismiss|DC4,0.1-60 -33355.420225119866
# GPU.S3|buy-dismiss|DC4,0.1-48 -29191.91152118444
# GPU.S3|buy-dismiss|DC4,0.1-36 -25745.7840853632
# GPU.S3|buy-dismiss|DC4,0.1-24 -22728.817819662836
# GPU.S3|buy-dismiss|DC4,0.1-12 -19730.673263952212
# GPU.S3|buy-dismiss|DC4,0.15-96 -62728.53012076094
# GPU.S3|buy-dismiss|DC4,0.15-84 -53419.725491556055
# GPU.S3|buy-dismiss|DC4,0.15-72 -46024.794747263
# GPU.S3|buy-dismiss|DC4,0.15-60 -40313.130337679795
# GPU.S3|buy-dismiss|DC4,0.15-48 -36011.86728177666
# GPU.S3|buy-dismiss|DC4,0.15-36 -32786.676128044804
# GPU.S3|buy-dismiss|DC4,0.15-24 -30205.22672949425
# GPU.S3|buy-dismiss|DC4,0.15-12 -27652.009895928317
# GPU.S3|buy-dismiss|DC4,0.2-96 -62902.04016101459
# GPU.S3|buy-dismiss|DC4,0.2-84 -53082.300655408086
# GPU.S3|buy-dismiss|DC4,0.2-72 -45814.39299635067
# GPU.S3|buy-dismiss|DC4,0.2-60 -40790.84045023973
# GPU.S3|buy-dismiss|DC4,0.2-48 -37647.82304236887
# GPU.S3|buy-dismiss|DC4,0.2-36 -35939.5681707264
# GPU.S3|buy-dismiss|DC4,0.2-24 -35089.635639325665
# GPU.S3|buy-dismiss|DC4,0.2-12 -34277.346527904425
# GPU.S3|buy-dismiss|DC4,0.25-96 -52707.55020126823
# GPU.S3|buy-dismiss|DC4,0.25-84 -43672.875819260094
# GPU.S3|buy-dismiss|DC4,0.25-72 -37827.99124543833
# GPU.S3|buy-dismiss|DC4,0.25-60 -34788.55056279966
# GPU.S3|buy-dismiss|DC4,0.25-48 -34099.7788029611
# GPU.S3|buy-dismiss|DC4,0.25-36 -35204.460213408
# GPU.S3|buy-dismiss|DC4,0.25-24 -37382.04454915708
# GPU.S3|buy-dismiss|DC4,0.25-12 -39606.68315988053
# GPU.S3|buy-dismiss|DC4,0.3-96 -32145.060241521867
# GPU.S3|buy-dismiss|DC4,0.3-84 -25191.450983112118
# GPU.S3|buy-dismiss|DC4,0.3-72 -22065.589494526
# GPU.S3|buy-dismiss|DC4,0.3-60 -22306.260675359594
# GPU.S3|buy-dismiss|DC4,0.3-48 -25367.734563553317
# GPU.S3|buy-dismiss|DC4,0.3-36 -30581.352256089598
# GPU.S3|buy-dismiss|DC4,0.3-24 -37082.4534589885
# GPU.S3|buy-dismiss|DC4,0.3-12 -43640.019791856634
# GPU.S3|buy-dismiss|DC4,0.35-96 -1214.5702817755518
# GPU.S3|buy-dismiss|DC4,0.35-84 2361.9738530358386
# GPU.S3|buy-dismiss|DC4,0.35-72 1472.8122563863144
# GPU.S3|buy-dismiss|DC4,0.35-60 -3343.970787919548
# GPU.S3|buy-dismiss|DC4,0.35-48 -11451.690324145551
# GPU.S3|buy-dismiss|DC4,0.35-36 -22070.2442987712
# GPU.S3|buy-dismiss|DC4,0.35-24 -34190.862368819915
# GPU.S3|buy-dismiss|DC4,0.35-12 -46377.356423832745
# GPU.S3|buy-dismiss|DC4,0.4-96 40083.91967797084
# GPU.S3|buy-dismiss|DC4,0.4-84 38987.39868918385
# GPU.S3|buy-dismiss|DC4,0.4-72 32787.21400729868
# GPU.S3|buy-dismiss|DC4,0.4-60 22098.319099520544
# GPU.S3|buy-dismiss|DC4,0.4-48 7648.353915262251
# GPU.S3|buy-dismiss|DC4,0.4-36 -9671.136341452788
# GPU.S3|buy-dismiss|DC4,0.4-24 -28707.271278651326
# GPU.S3|buy-dismiss|DC4,0.4-12 -47818.69305580885
# GPU.S3|buy-dismiss|DC4,0.45-96 91750.40963771718
# GPU.S3|buy-dismiss|DC4,0.45-84 84684.82352533186
# GPU.S3|buy-dismiss|DC4,0.45-72 71877.61575821103
# GPU.S3|buy-dismiss|DC4,0.45-60 54020.60898696062
# GPU.S3|buy-dismiss|DC4,0.45-48 31932.398154670023
# GPU.S3|buy-dismiss|DC4,0.45-36 6615.9716158656065
# GPU.S3|buy-dismiss|DC4,0.45-24 -20631.680188482755
# GPU.S3|buy-dismiss|DC4,0.45-12 -47964.02968778494
# GPU.S3|buy-dismiss|DC4,0.5-96 153784.89959746355
# GPU.S3|buy-dismiss|DC4,0.5-84 139454.24836147978
# GPU.S3|buy-dismiss|DC4,0.5-72 118744.01750912334
# GPU.S3|buy-dismiss|DC4,0.5-60 92422.8988744007
# GPU.S3|buy-dismiss|DC4,0.5-48 61400.44239407779
# GPU.S3|buy-dismiss|DC4,0.5-36 26791.079573184015
# GPU.S3|buy-dismiss|DC4,0.5-24 -9964.089098314158
# GPU.S3|buy-dismiss|DC4,0.5-12 -46813.36631976106
# GPU.S3|buy-dismiss|DC4,0.55-96 226187.38955721
# GPU.S3|buy-dismiss|DC4,0.55-84 203295.67319762785
# GPU.S3|buy-dismiss|DC4,0.55-72 173386.41926003576
# GPU.S3|buy-dismiss|DC4,0.55-60 137305.18876184084
# GPU.S3|buy-dismiss|DC4,0.55-48 96052.48663348565
# GPU.S3|buy-dismiss|DC4,0.55-36 50854.18753050246
# GPU.S3|buy-dismiss|DC4,0.55-24 3295.501991854464
# GPU.S3|buy-dismiss|DC4,0.55-12 -44366.70295173715
# GPU.S3|buy-dismiss|DC4,0.6-96 308957.8795169562
# GPU.S3|buy-dismiss|DC4,0.6-84 276209.09803377575
# GPU.S3|buy-dismiss|DC4,0.6-72 235804.82101094798
# GPU.S3|buy-dismiss|DC4,0.6-60 188667.4786492808
# GPU.S3|buy-dismiss|DC4,0.6-48 135888.53087289335
# GPU.S3|buy-dismiss|DC4,0.6-36 78805.2954878208
# GPU.S3|buy-dismiss|DC4,0.6-24 19147.093082023
# GPU.S3|buy-dismiss|DC4,0.6-12 -40624.039583713275
# GPU.S3|buy-dismiss|DC4,0.65-96 402096.3694767026
# GPU.S3|buy-dismiss|DC4,0.65-84 358194.52286992373
# GPU.S3|buy-dismiss|DC4,0.65-72 305999.22276186035
# GPU.S3|buy-dismiss|DC4,0.65-60 246509.7685367209
# GPU.S3|buy-dismiss|DC4,0.65-48 180908.57511230116
# GPU.S3|buy-dismiss|DC4,0.65-36 110644.40344513922
# GPU.S3|buy-dismiss|DC4,0.65-24 37590.684172191606
# GPU.S3|buy-dismiss|DC4,0.65-12 -35585.37621568938
# GPU.S3|buy-dismiss|DC4,0.7-96 505602.85943644884
# GPU.S3|buy-dismiss|DC4,0.7-84 449251.94770607154
# GPU.S3|buy-dismiss|DC4,0.7-72 383969.62451277254
# GPU.S3|buy-dismiss|DC4,0.7-60 310832.0584241609
# GPU.S3|buy-dismiss|DC4,0.7-48 231112.61935170885
# GPU.S3|buy-dismiss|DC4,0.7-36 146371.51140245755
# GPU.S3|buy-dismiss|DC4,0.7-24 58626.275262360155
# GPU.S3|buy-dismiss|DC4,0.7-12 -29250.712847665498
# GPU.S3|buy-dismiss|DC4,0.75-96 619477.3493961953
# GPU.S3|buy-dismiss|DC4,0.75-84 549381.3725422197
# GPU.S3|buy-dismiss|DC4,0.75-72 469716.0262636851
# GPU.S3|buy-dismiss|DC4,0.75-60 381634.34831160103
# GPU.S3|buy-dismiss|DC4,0.75-48 286500.6635911167
# GPU.S3|buy-dismiss|DC4,0.75-36 185986.61935977603
# GPU.S3|buy-dismiss|DC4,0.75-24 82253.86635252877
# GPU.S3|buy-dismiss|DC4,0.75-12 -21620.049479641588
# GPU.S3|buy-dismiss|DC4,0.8-96 743719.8393559416
# GPU.S3|buy-dismiss|DC4,0.8-84 658582.7973783677
# GPU.S3|buy-dismiss|DC4,0.8-72 563238.4280145974
# GPU.S3|buy-dismiss|DC4,0.8-60 458916.63819904113
# GPU.S3|buy-dismiss|DC4,0.8-48 347072.70783052454
# GPU.S3|buy-dismiss|DC4,0.8-36 229489.7273170944
# GPU.S3|buy-dismiss|DC4,0.8-24 108473.45744269734
# GPU.S3|buy-dismiss|DC4,0.8-12 -12693.386111617674
# GPU.S3|buy-dismiss|DC4,0.85-96 878330.329315688
# GPU.S3|buy-dismiss|DC4,0.85-84 776856.2222145157
# GPU.S3|buy-dismiss|DC4,0.85-72 664536.8297655097
# GPU.S3|buy-dismiss|DC4,0.85-60 542678.9280864812
# GPU.S3|buy-dismiss|DC4,0.85-48 412828.7520699323
# GPU.S3|buy-dismiss|DC4,0.85-36 276880.8352744129
# GPU.S3|buy-dismiss|DC4,0.85-24 137285.04853286597
# GPU.S3|buy-dismiss|DC4,0.85-12 -2470.722743593793
# GPU.S3|buy-dismiss|DC4,0.9-96 1023308.8192754345
# GPU.S3|buy-dismiss|DC4,0.9-84 904201.6470506636
# GPU.S3|buy-dismiss|DC4,0.9-72 773611.231516422
# GPU.S3|buy-dismiss|DC4,0.9-60 632921.2179739213
# GPU.S3|buy-dismiss|DC4,0.9-48 483768.79630934005
# GPU.S3|buy-dismiss|DC4,0.9-36 328159.94323173125
# GPU.S3|buy-dismiss|DC4,0.9-24 168688.63962303454
# GPU.S3|buy-dismiss|DC4,0.9-12 9047.940624430108
# GPU.S3|buy-dismiss|DC4,0.95-96 1178655.3092351807
# GPU.S3|buy-dismiss|DC4,0.95-84 1040619.0718868115
# GPU.S3|buy-dismiss|DC4,0.95-72 890461.6332673344
# GPU.S3|buy-dismiss|DC4,0.95-60 729643.5078613613
# GPU.S3|buy-dismiss|DC4,0.95-48 559892.8405487479
# GPU.S3|buy-dismiss|DC4,0.95-36 383327.0511890496
# GPU.S3|buy-dismiss|DC4,0.95-24 202684.23071320314
# GPU.S3|buy-dismiss|DC4,0.95-12 21862.60399245398
# GPU.S3|buy-dismiss|DC4,1.0-96 1344369.7991949269
# GPU.S3|buy-dismiss|DC4,1.0-84 1186108.4967229597
# GPU.S3|buy-dismiss|DC4,1.0-72 1015088.0350182466
# GPU.S3|buy-dismiss|DC4,1.0-60 832845.7977488013
# GPU.S3|buy-dismiss|DC4,1.0-48 641200.8847881556
# GPU.S3|buy-dismiss|DC4,1.0-36 442382.159146368
# GPU.S3|buy-dismiss|DC4,1.0-24 239271.82180337168
# GPU.S3|buy-dismiss|DC4,1.0-12 35973.26736047789

# %%
df_results = pd.DataFrame(df_results, columns=['action_string', 'score'])
df_results['server_generation'] = df_results['action_string'].apply(lambda x: x.split("|")[0])
df_results = pd.DataFrame.join(df_results.set_index('server_generation'),
                  df_servers[['server_generation', 'slots_size']].set_index('server_generation'), 
                  on='server_generation', how='left').reset_index()
df_results['score_per_slot'] = df_results['score'] / df_results['slots_size']
df_results = df_results.sort_values(by=['score_per_slot', 'action_string'], ascending=False).reset_index(drop=True)
df_results.to_csv("df_single_server_results_v6_buydismiss_UP.csv", index=False)
df_results
# Out:
#      server_generation                   action_string         score  \
# 0               GPU.S3   GPU.S3|buy-dismiss|DC3,1.0-96  1.384690e+06
# 1               GPU.S3   GPU.S3|buy-dismiss|DC4,1.0-96  1.344370e+06
# 2               GPU.S3   GPU.S3|buy-dismiss|DC2,1.0-96  1.313650e+06
# 3               GPU.S3   GPU.S3|buy-dismiss|DC3,1.0-84  1.221388e+06
# 4               GPU.S3  GPU.S3|buy-dismiss|DC3,0.95-96  1.216959e+06
# ...                ...                             ...           ...
# 4475            GPU.S3   GPU.S3|buy-dismiss|DC3,0.2-96 -5.483804e+04
# 4476            GPU.S2   GPU.S2|buy-dismiss|DC4,0.2-96 -5.645529e+04
# 4477            GPU.S3  GPU.S3|buy-dismiss|DC3,0.15-96 -5.668053e+04
# 4478            GPU.S3  GPU.S3|buy-dismiss|DC4,0.15-96 -6.272853e+04
# 4479            GPU.S3   GPU.S3|buy-dismiss|DC4,0.2-96 -6.290204e+04
#
#       slots_size  score_per_slot
# 0              4   346172.449799
# 1              4   336092.449799
# 2              4   328412.449799
# 3              4   305347.124181
# 4              4   304239.827309
# ...          ...             ...
# 4475           4   -13709.510040
# 4476           4   -14113.821285
# 4477           4   -14170.132530
# 4478           4   -15682.132530
# 4479           4   -15725.510040
#
# [4480 rows x 5 columns]

# %% [markdown]
# # buy-move-dismiss

# %% [markdown]
# ### simulation

# %%
import re

df_results = []
for action_string in ["GPU.S3|buy-move-dismiss|DC3,0.5-DC2,0.5,86-96"]:
    action_comb = parse_action_string(action_string)
    solution = get_solution_from_action_comb(action_comb)
    server_generation = action_comb[0]["server_generation"]
    latency_sensitivity_1 = df_datacenters[df_datacenters['datacenter_id'] == action_comb[0]["datacenter_id"]]['latency_sensitivity'].iloc[0]
    latency_sensitivity_2 = df_datacenters[df_datacenters['datacenter_id'] == action_comb[1]["datacenter_id"]]['latency_sensitivity'].iloc[0]

    server_capacity = df_servers[df_servers['server_generation'] == server_generation]['capacity'].iloc[0]
    average_U = action_comb[0]["average_U"]
    demand = pd.DataFrame({
        "time_step": list(range(1,168+1)),
        "server_generation": [server_generation]*168,
        "high": [0]*168,
        "medium": [0]*168,
        "low": [0]*168
    })
    demand[latency_sensitivity_1] = server_capacity * average_U
    demand[latency_sensitivity_2] = server_capacity * average_U

    score = evaluation_nofail.get_evaluation(solution, 
                                            demand,
                                            datacenters,
                                            servers,
                                            selling_prices,
                                            time_steps=196, 
                                            verbose=False,
                                            random_demand=False)
    real_score = evaluation_fail.get_evaluation(solution, 
                                            demand,
                                            datacenters,
                                            servers,
                                            selling_prices,
                                            time_steps=196, 
                                            verbose=False,
                                            random_demand=False)

    print(action_string, score, real_score)
    df_results.append([action_string, score, real_score])
df_results = pd.DataFrame(df_results, columns=['action_string', 'score', 'real_score'])
# Out:
# GPU.S3|buy-move-dismiss|DC3,0.5-DC2,0.5,86-96 112586.80038495417 128670.6290113762

# %% [markdown]
# ### formula

# %%
from utils import (load_problem_data,
                   load_solution)
from evaluation import evaluation_function, get_known, get_evaluation
import pandas as pd
import numpy as np

demand, datacenters, servers, selling_prices = load_problem_data(path='./data_test')

df_servers = pd.read_csv('./data/servers.csv')
df_datacenters = pd.read_csv('./data/datacenters.csv')
df_selling_price = pd.read_csv('./data/selling_prices.csv')

# %%
df_servers_dict = df_servers.set_index('server_generation').to_dict('index')
df_datacenters_dict = df_datacenters.set_index('datacenter_id').to_dict('index')
df_selling_price_dict = df_selling_price.set_index(['server_generation', 'latency_sensitivity']).to_dict('index')

# %%
df_selling_price_dict[('CPU.S1', 'medium')]
# Out:
# {'selling_price': 15.0}

# %%
('CPU.S1', 'medium')
# Out:
# ('CPU.S1', 'medium')

# %%
list_action_strings = []
for server_generation in df_servers['server_generation'].values:
    life_expectancy = df_servers_dict[server_generation]['life_expectancy']

    for datacenter_id_1 in df_datacenters['datacenter_id'].values:
        for datacenter_id_2 in df_datacenters['datacenter_id'].values:
            if datacenter_id_1 == datacenter_id_2:
                continue
            for average_U_1 in np.linspace(0.0, 1.0, 21)[1:]:
                for average_U_2 in np.linspace(0.0, 1.0, 21)[1:]:

                    for dismiss_age in range(life_expectancy, 0, -12):
                        for move_age in range(life_expectancy, 0, -12):
                            if move_age >= dismiss_age:
                                continue
                            action_string = f"{server_generation}|buy-move-dismiss|{datacenter_id_1},{np.round(average_U_1,2)}-{datacenter_id_2},{np.round(average_U_2,2)},{move_age}-{dismiss_age}"
                            list_action_strings.append(action_string)
len(list_action_strings)
# Out:
# 940800

# %%
import concurrent.futures
from tqdm import tqdm



df_results = []
for action_string in tqdm(list_action_strings):
    action_comb = parse_action_string(action_string)

    server_generation = action_comb[0]["server_generation"]
    datacenter_id_1 = action_comb[0]["datacenter_id"]
    datacenter_id_2 = action_comb[1]["datacenter_id"]

    average_U_1 = action_comb[0]["average_U"]
    average_U_2 = action_comb[1]["average_U"]

    df_cur_server = df_servers_dict[server_generation]
    df_cur_datacenter_1 = df_datacenters_dict[datacenter_id_1]
    df_cur_datacenter_2 = df_datacenters_dict[datacenter_id_2]

    cost_of_energy_1 = df_cur_datacenter_1['cost_of_energy']
    latency_sensitivity_1 = df_cur_datacenter_1['latency_sensitivity']

    cost_of_energy_2 = df_cur_datacenter_2['cost_of_energy']
    latency_sensitivity_2 = df_cur_datacenter_2['latency_sensitivity']


    selling_price_1 = df_selling_price_dict[(server_generation,latency_sensitivity_1)]['selling_price']
    selling_price_2 = df_selling_price_dict[(server_generation,latency_sensitivity_2)]['selling_price']

    energy_consumption_per_day = df_cur_server['energy_consumption']
    energy_cost_per_day_1 = energy_consumption_per_day * cost_of_energy_1
    energy_cost_per_day_2 = energy_consumption_per_day * cost_of_energy_2


    life_expectancy = df_cur_server['life_expectancy']
    purchase_price = df_cur_server['purchase_price']
    average_mantainance_cost_per_day = df_cur_server['average_maintenance_fee']
    server_capacity = df_cur_server['capacity']
    cost_of_moving = df_cur_server['cost_of_moving']

    move_age = action_comb[1]["move_age"]
    dismiss_age = action_comb[2]["dismiss_age"]
    failure_rate = 0.0
    # failure_rate = 0.07260491698699582
    
    list_objective_per_day = []
    for i in range(1, dismiss_age+1):
        selling_price = selling_price_1 if i < move_age + 1 else selling_price_2
        energy_cost_per_day = energy_cost_per_day_1 if i < move_age + 1 else energy_cost_per_day_2
        average_U = average_U_1 if i < move_age + 1 else average_U_2
        Z_fail = int((1-failure_rate) * server_capacity)
        demand_met = np.minimum(Z_fail, average_U * server_capacity)

        U = demand_met / Z_fail
        L = i / life_expectancy
        R = demand_met * selling_price
        C = average_mantainance_cost_per_day * (1 + 1.5 * i / life_expectancy * np.log2(1.5 * i / life_expectancy)) + energy_cost_per_day
        if i == 1:
            C += purchase_price
        if i == move_age + 1:
            C += cost_of_moving
        P = R - C
        # print(i, U, np.round(L,2), P)
        list_objective_per_day.append([U, L, P])


    list_objective_per_day = np.asarray(list_objective_per_day)
    objective_per_day = list_objective_per_day[:,0] * list_objective_per_day[:,2]
    total_objective = np.sum(objective_per_day)

    df_results.append([action_string, total_objective])
df_results = pd.DataFrame(df_results, columns=['action_string', 'score'])
df_results
# Out:
# 100%|██████████| 940800/940800 [03:25<00:00, 4585.47it/s]
#                                           action_string          score
# 0       CPU.S1|buy-move-dismiss|DC1,0.05-DC2,0.05,84-96   -2398.517822
# 1       CPU.S1|buy-move-dismiss|DC1,0.05-DC2,0.05,72-96   -2413.517822
# 2       CPU.S1|buy-move-dismiss|DC1,0.05-DC2,0.05,60-96   -2428.517822
# 3       CPU.S1|buy-move-dismiss|DC1,0.05-DC2,0.05,48-96   -2443.517822
# 4       CPU.S1|buy-move-dismiss|DC1,0.05-DC2,0.05,36-96   -2458.517822
# ...                                                 ...            ...
# 940795    GPU.S3|buy-move-dismiss|DC4,1.0-DC3,1.0,24-48  650280.884788
# 940796    GPU.S3|buy-move-dismiss|DC4,1.0-DC3,1.0,12-48  655320.884788
# 940797    GPU.S3|buy-move-dismiss|DC4,1.0-DC3,1.0,24-36  446422.159146
# 940798    GPU.S3|buy-move-dismiss|DC4,1.0-DC3,1.0,12-36  451462.159146
# 940799    GPU.S3|buy-move-dismiss|DC4,1.0-DC3,1.0,12-24  243311.821803
#
# [940800 rows x 2 columns]

# %%
df_results = pd.DataFrame(df_results, columns=['action_string', 'score'])
df_results['server_generation'] = df_results['action_string'].apply(lambda x: x.split("|")[0])
df_results = pd.DataFrame.join(df_results.set_index('server_generation'),
                  df_servers[['server_generation', 'slots_size']].set_index('server_generation'), 
                  on='server_generation', how='left').reset_index()
df_results['score_per_slot'] = df_results['score'] / df_results['slots_size']
df_results = df_results.sort_values(by=['score_per_slot', 'action_string'], ascending=False).reset_index(drop=True)
df_results.to_csv("df_single_server_results_v6_buymovedismiss_UP.csv", index=False)
df_results
# Out:
#        server_generation                                    action_string  \
# 0                 GPU.S3    GPU.S3|buy-move-dismiss|DC4,1.0-DC3,1.0,12-96
# 1                 GPU.S3    GPU.S3|buy-move-dismiss|DC3,1.0-DC4,1.0,84-96
# 2                 GPU.S3    GPU.S3|buy-move-dismiss|DC3,1.0-DC2,1.0,84-96
# 3                 GPU.S3    GPU.S3|buy-move-dismiss|DC2,1.0-DC3,1.0,12-96
# 4                 GPU.S3    GPU.S3|buy-move-dismiss|DC4,1.0-DC3,1.0,24-96
# ...                  ...                                              ...
# 940795            GPU.S3   GPU.S3|buy-move-dismiss|DC3,0.4-DC4,0.15,12-96
# 940796            GPU.S3   GPU.S3|buy-move-dismiss|DC1,0.4-DC4,0.15,12-96
# 940797            GPU.S3  GPU.S3|buy-move-dismiss|DC1,0.55-DC4,0.15,12-96
# 940798            GPU.S3  GPU.S3|buy-move-dismiss|DC1,0.45-DC4,0.15,12-96
# 940799            GPU.S3   GPU.S3|buy-move-dismiss|DC1,0.5-DC4,0.15,12-96
#
#                score  slots_size  score_per_slot
# 0       1.378650e+06           4   344662.449799
# 1       1.378650e+06           4   344662.449799
# 2       1.374810e+06           4   343702.449799
# 3       1.374810e+06           4   343702.449799
# 4       1.373610e+06           4   343402.449799
# ...              ...         ...             ...
# 940795 -8.102921e+04           4   -20257.303320
# 940796 -8.141321e+04           4   -20353.303320
# 940797 -8.170522e+04           4   -20426.305794
# 940798 -8.254255e+04           4   -20635.637478
# 940799 -8.263989e+04           4   -20659.971636
#
# [940800 rows x 5 columns]
